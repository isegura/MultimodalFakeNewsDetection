# %% [markdown]
# # CNN (text + images)

# %%
# Import libraries
import numpy as np
import time
import os
import matplotlib
import matplotlib.image as mpimg
import pandas as pd
from torch import optim
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('punkt')
from sklearn.feature_extraction.text import CountVectorizer
import re
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
import spacy
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.preprocessing.sequence import pad_sequences
import torch
from torch.utils.data import TensorDataset, DataLoader, Dataset
import torch.nn as nn
import torch.nn.functional as F
import cv2 
import multiprocessing as mp
import FunctionsTFM 
import imp
import threading


# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\santi_s09ykpb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\santi_s09ykpb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# First we get the data.

# %%
# Train data 
traindata_all = pd.read_csv('C:\\TFM\\Data\\multimodal_train.tsv', sep='\t')
# Validation data 
validata_all = pd.read_csv('C:\\TFM\\Data\\multimodal_validate.tsv', sep='\t')
# Test data 
testdata_all = pd.read_csv('C:\\TFM\\Data\\multimodal_test_public.tsv', sep='\t')

# %% [markdown]
# Select a subset of the dataframe with no missing values in the 'title' column.

# %%
# Train data with no missing values
train_data = traindata_all[traindata_all['title'].notnull().to_numpy()]
# Validation data with no missing values
valid_data = validata_all[validata_all['title'].notnull().to_numpy()]
# Test data with no missing values
test_data = testdata_all[testdata_all['title'].notnull().to_numpy()]

# %% [markdown]
# Separate the dataset into the texts, labels and image names

# %%
## Train data
train_news = list(train_data['title'])
train_labels = list(train_data['6_way_label'])
train_images = list(train_data['id'])
## Valid data
valid_news = list(valid_data['title'])
valid_labels = list(valid_data['6_way_label'])
valid_images = list(valid_data['id'])
## Test data
test_news = list(test_data['title'])
test_labels = list(test_data['6_way_label'])
test_images = list(test_data['id'])

# %% [markdown]
# Now we add the **'.jpg'** termination to all the image names in the previous lists.

# %%
# Train
train_images_final = [image + '.jpg' for image in train_images]
# Validation
valid_images_final = [image + '.jpg' for image in valid_images]
# Test
test_images_final = [image + '.jpg' for image in test_images]

# %% [markdown]
# ## Preprocessing
#
# First we neet to preprocess the text that we will feed to the neural network. We define a function to preprocess the data. We remove punctuations, numbers and also multiple spaces.

# %%
def preprocess_text(sen):
    # Remove punctuations and numbers
    sentence = re.sub('[^a-zA-Z]', ' ', sen)

    # Removing multiple spaces
    sentence = re.sub(r'\s+', ' ', sentence)

    return sentence

# %%
# Remove puntuations and numbers and multiple spaces

train_news_clean_1 = []
valid_news_clean_1 = []
test_news_clean_1 = []
# Train
for new in train_news:
    train_news_clean_1.append(preprocess_text(new))
# Validation
for new in valid_news:
    valid_news_clean_1.append(preprocess_text(new))
# Test
for new in test_news:
    test_news_clean_1.append(preprocess_text(new))

# %%
# Initialize  lemmatizer and  stop_words

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english')) 

# Function to remove stopwords
def remove_stopwords_lem(text):
    text = word_tokenize(text)
    # Remove stopwords
    text = [word for word in text if word not in stop_words]
    # Lematization
    lemmatized_text = []
    for word in text:
        word1 = lemmatizer.lemmatize(word, pos = "n")
        word2 = lemmatizer.lemmatize(word1, pos = "v")
        word3 = lemmatizer.lemmatize(word2, pos = ("a"))
        lemmatized_text.append(word3)
        
    text_done = ' '.join(lemmatized_text)
    return text_done

# %% [markdown]
# And now we perform stop-words removal and lemmatization

# %%
# Stop-words removal and lemmatization
train_stwrd_lem = []
valid_stwrd_lem = []
test_stwrd_lem = []

# Train
for new in train_news_clean_1:
    train_stwrd_lem.append(remove_stopwords_lem(new))
# Validation
for new in valid_news_clean_1:
    valid_stwrd_lem.append(remove_stopwords_lem(new))
# Test
for new in test_news_clean_1:
    test_stwrd_lem.append(remove_stopwords_lem(new))

# %% [markdown]
# And now we tokenize the news. For that we train a tokenizer using all the vocabulary.

# %%
news_all = train_stwrd_lem + valid_stwrd_lem + test_stwrd_lem

tokenizer = Tokenizer(num_words = 128022)
tokenizer.fit_on_texts(news_all)

# Tokenize news

# Train
train_tokenized = tokenizer.texts_to_sequences(train_stwrd_lem)
# Validation
valid_tokenized = tokenizer.texts_to_sequences(valid_stwrd_lem)
# Test
test_tokenized = tokenizer.texts_to_sequences(test_stwrd_lem)

# %% [markdown]
# Obtain the vocabulary length

# %%
print("Vocabulary length: ", len(tokenizer.word_index))
# Out:
# Vocabulary length:  109845

# %% [markdown]
# Now we pad the sequences of numbers generated by the tokenizer. We select **15** as the lenght of the padded/truncated sequences since, as can be seen in the 'CNN.ipynb' and in the  'BiLSTM.ipynb' codes, almos all news are shorter than this, so very little information will be lost.

# %%
# Pad/truncate the tokenized news

# Train
train_tokenized_pad = pad_sequences(train_tokenized, maxlen = 15, truncating = 'post', padding = 'post')
# Validation
valid_tokenized_pad = pad_sequences(valid_tokenized, maxlen = 15, truncating = 'post', padding = 'post')
# Test
test_tokenized_pad = pad_sequences(test_tokenized, maxlen = 15, truncating = 'post', padding = 'post')

# %% [markdown]
# ## Training the model
#
# We create a function to load the word embeddings and another one to create the embedding matrix.

# %%
# Function to load the word embeddings

def load_embedd(filename):
    words = []
    vectors = []
    file = open(filename,'r', encoding="utf8")
    for line in file.readlines():
       row = line.split(' ')
       vocab = row[0]
       embd = row[1:len(row)]
       embd[-1] = embd[-1].rstrip()
       embd = list(map(float,embd)) # convert string to float
       words.append(vocab)
       vectors.append(embd)
    file.close()
    return words,vectors

# %%
# Function embed matrix

def embed_matx(word_index, vocab, embeddings, length_vocab, length_embedding):
    embedding_matrix = np.zeros((length_vocab +1, length_embedding))
    for word, i in word_index.items():
        if word in vocab:
            idx = vocab.index(word)
            vector =  embeddings[idx]
            embedding_matrix[i] = vector
        if i == length_vocab:
            break
    return embedding_matrix

# %% [markdown]
# #### GloVe (300 d)
#
# Obtain the vocabulary and the vectors of the embedding matrix. We use GloVe embeddings of dimension 300.

# %%
vocab_gv_300, vectors_gv_300 = load_embedd(filename = "H:\\TFM\\Glove_embeddings\\glove.6B.300d.txt")

# %% [markdown]
# Create the embedding matrix.

# %%
word_index = tokenizer.word_index
# Embedding matrix
embedding_matrix_gv_300 = embed_matx(word_index = word_index, vocab = vocab_gv_300, embeddings = vectors_gv_300, 
                             length_vocab = 109845, length_embedding = 300)

# %%
# Get names of available images
all_images = os.listdir("C:\\TFM\\Data\\public_image_set")

# Path to the images folder

PATH = "C:\\TFM\\Data\\public_image_set\\"

# %% [markdown]
# In order to feed the images to the CNN these need to be of the same size therefore we will have to pad the images with zeros or truncate them so that all are of the size **560 x 560**. In order to achieve that we define the following function.

# %%
# Funtion to pad/truncate images to shape 560 x 560

def pad_images(image):
     img_reshaped = np.zeros((3, 560, 560))
     if image.shape[0] > 560 and image.shape[1] > 560:
       img_reshaped[0, :, :] = image[0:560,0:560,0]
       img_reshaped[1, :, :] = image[0:560,0:560,1]
       img_reshaped[2, :, :] = image[0:560,0:560,2]
     if image.shape[0] > 560 and image.shape[1] <= 560:
       img_reshaped[0, :, 0:image.shape[1]] = image[0:560,:,0]
       img_reshaped[1, :, 0:image.shape[1]] = image[0:560,:,1]
       img_reshaped[2, :, 0:image.shape[1]] = image[0:560,:,2]
     if image.shape[0] <= 560 and image.shape[1] > 560:
       img_reshaped[0, 0:image.shape[0], :] = image[:,0:560,0]
       img_reshaped[1, 0:image.shape[0], :] = image[:,0:560,1]
       img_reshaped[2, 0:image.shape[0], :] = image[:,0:560,2]
     if image.shape[0] < 560 and image.shape[1] < 560:
       img_reshaped[0, 0:image.shape[0], 0:image.shape[1]] = image[:,:,0]
       img_reshaped[1, 0:image.shape[0], 0:image.shape[1]] = image[:,:,1]
       img_reshaped[2, 0:image.shape[0], 0:image.shape[1]] = image[:,:,2]
     return img_reshaped

# %% [markdown]
# ## Model
#
# We also define the different layers that we will be using for  the model.

# %%
# Create model

class CNN_title_images(nn.Module):
    
  def __init__(self,image_dimx,nlabels):
    
     super().__init__()
        
     # Embedding layer 
     self.embedding = nn.Embedding(num_embeddings =109846, embedding_dim = 300)
     self.embedding.weight = nn.Parameter(torch.from_numpy(embedding_matrix_gv_300), requires_grad = False)

     # Convolutional layers (for the images)
     self.conv1 = nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1, padding=0)
     self.conv2 = nn.Conv2d(in_channels=6, out_channels=3, kernel_size=5, stride=1, padding=0)

     # Convolutional layer (for the titles)
     self.filter_sizes = [2,3,4,5]
     self.num_filters = 50
     self.convs_concat = nn.ModuleList([nn.Conv2d(1, self.num_filters, (K, 300)) for K in self.filter_sizes])

     # Pooling layer
     self.maxlayer1 = nn.MaxPool2d(2, 2)

     # Linear layers
     self.linear1 = nn.Linear(200 + 3*137*137,256)
     self.linear2 = nn.Linear(256,nlabels)
     self.linear3 = nn.Linear(128,nlabels)

     # Relu activation
     self.relu = nn.ReLU()

     # Logsoftmax function
     self.logsoftmax = nn.LogSoftmax(dim=1) 

     # Dimension of the image at the output of the second convolutional layer
     self.final_dim = int(((image_dimx-4)/2-4)/2)
        
  def forward(self, x_image, x_title):
        # Pass the image tensor through the CNN operations
        x_image = self.conv1(x_image) 
        x_image = self.relu(x_image) 
        x_image = self.maxlayer1(x_image)
        x_image = self.conv2(x_image)
        x_image = self.relu(x_image)
        x_image = self.maxlayer1(x_image)
        x_image = x_image.view(x_image.shape[0],self.final_dim*self.final_dim*3)
        # Pass the text tensor through the different operations
        x_title = self.embedding(x_title)
        x_title = x_title.unsqueeze(1)
        x_title = [F.relu(conv(x_title.float())).squeeze(3) for conv in self.convs_concat]
        x_title = [F.max_pool1d(i, i.size(2)).squeeze(2) for i in x_title] 
        x_title = torch.cat(x_title, 1)
        # Join text and image output
        x = torch.cat([x_image,x_title ],1)
        # Pass result through linear layers
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        x = self.logsoftmax(x) 
        return x

# %% [markdown]
# ### Optimal number of epochs
#
# We instantiate the class

# %%
# Instantiate the model
model_CNN_image_text = CNN_title_images(image_dimx = 560 ,nlabels = 6 )

# %% [markdown]
# ### Optimal number of epochs
#
# We train the model for **1**, **2** and **3** epochs and we select the number of epochs that results in the highest validation accuracy.
#
# **NOTE**: run the code in the cell bellow once for 1 epochs, twice for 2 epochs and trice for 3 epochs. In each case, run also the cell that follows the cell below to obtain the corresponding validation accuracy.

# %%
# Create counter to be used in the loop
counter = 0
# List to store the images
list_images = []
# List to store the titles
list_titles = []
# List to store the labels
list_labels = []
# To count the number of batches
repetitions_train = 0
repetitions_valid = 0
# Error function
criterion = nn.NLLLoss()
# Optimizer
optimizer = torch.optim.Adam(model_CNN_image_text.parameters(), lr = 0.001)
# To store train accuracy
accuracy_train = 0
# To store valation accuracy
accuracy_valid = 0
#  Loop to train the model

images_tensor = torch.zeros(60,3,560,560)
titles_tensor = torch.zeros(60,15)
labels_tensor = torch.zeros(60)

for i in range(0, len(train_images_final)):
    
    # First check if image is available
    img = cv2.imread(PATH + train_images_final[i])   
        
    if type(img) is not type(None):
                          
        counter += 1
        
        # Pad it with zeros or truncate it to obtain 560 x 560 shape
        
        img_padded = pad_images(img)
        
        # Store image and corresponding title and label 
        images_tensor[counter-1, :,:,:] = torch.from_numpy(img_padded)
        titles_tensor[counter-1, :] = torch.from_numpy(train_tokenized_pad[i]).int()
        labels_tensor[counter - 1] = train_labels[i]    
        
        # When 'batch_size' obervations are stored create DataLoader objects 
        
        if counter%60 == 0:
            
           repetitions_train += 1
           print("Batch interaction: ", repetitions_train)

           # Reset gradients
           optimizer.zero_grad() 

           # Pass image and text through the different layers
            
           out = model_CNN_image_text.forward(images_tensor, titles_tensor.long())         
            
           # Compute loss
        
           loss = criterion(out,labels_tensor.long())
            
           # Backpropagation
           
           loss.backward()
        
           # Optimize parameters
            
           optimizer.step()
            
           # Obtain number of correct predictions and store accuracy
            
           top_p, top_class = out.topk(1, dim=1) 
           equals = (top_class == labels_tensor.view(images_tensor.shape[0], 1))
           accuracy_train += torch.mean(equals.type(torch.FloatTensor))
        
           images_tensor = torch.zeros(60,3,560,560)
           titles_tensor = torch.zeros(60,15)
           labels_tensor = torch.zeros(60)
            
           counter = 0 
                
           # Every 100 repetitions print accuracy
           if repetitions_train%100 == 0:
                print("Training accuracy:", accuracy_train/repetitions_train)
# Out:
# Batch interaction:  1
# Batch interaction:  2
# Batch interaction:  3
# Batch interaction:  4
# Batch interaction:  5
# Batch interaction:  6
# Batch interaction:  7
# Batch interaction:  8
# Batch interaction:  9
# Batch interaction:  10
# Batch interaction:  11
# Batch interaction:  12
# Batch interaction:  13
# Batch interaction:  14
# Batch interaction:  15
# Batch interaction:  16
# Batch interaction:  17
# Batch interaction:  18
# Batch interaction:  19
# Batch interaction:  20
# Batch interaction:  21
# Batch interaction:  22
# Batch interaction:  23
# Batch interaction:  24
# Batch interaction:  25
# Batch interaction:  26
# Batch interaction:  27
# Batch interaction:  28
# Batch interaction:  29
# Batch interaction:  30
# Batch interaction:  31
# Batch interaction:  32
# Batch interaction:  33
# Batch interaction:  34
# Batch interaction:  35
# Batch interaction:  36
# Batch interaction:  37
# Batch interaction:  38
# Batch interaction:  39
# Batch interaction:  40
# Batch interaction:  41
# Batch interaction:  42
# Batch interaction:  43
# Batch interaction:  44
# Batch interaction:  45
# Batch interaction:  46
# Batch interaction:  47
# Batch interaction:  48
# Batch interaction:  49
# Batch interaction:  50
# Batch interaction:  51
# Batch interaction:  52
# Batch interaction:  53
# Batch interaction:  54
# Batch interaction:  55
# Batch interaction:  56
# Batch interaction:  57
# Batch interaction:  58
# Batch interaction:  59
# Batch interaction:  60
# Batch interaction:  61
# Batch interaction:  62
# Batch interaction:  63
# Batch interaction:  64
# Batch interaction:  65
# Batch interaction:  66
# Batch interaction:  67
# Batch interaction:  68
# Batch interaction:  69
# Batch interaction:  70
# Batch interaction:  71
# Batch interaction:  72
# Batch interaction:  73
# Batch interaction:  74
# Batch interaction:  75
# Batch interaction:  76
# Batch interaction:  77
# Batch interaction:  78
# Batch interaction:  79
# Batch interaction:  80
# Batch interaction:  81
# Batch interaction:  82
# Batch interaction:  83
# Batch interaction:  84
# Batch interaction:  85
# Batch interaction:  86
# Batch interaction:  87
# Batch interaction:  88
# Batch interaction:  89
# Batch interaction:  90
# Batch interaction:  91
# Batch interaction:  92
# Batch interaction:  93
# Batch interaction:  94
# Batch interaction:  95
# Batch interaction:  96
# Batch interaction:  97
# Batch interaction:  98
# Batch interaction:  99
# Batch interaction:  100
# Training accuracy: tensor(0.8832)
# Batch interaction:  101
# Batch interaction:  102
# Batch interaction:  103
# Batch interaction:  104
# Batch interaction:  105
# Batch interaction:  106
# Batch interaction:  107
# Batch interaction:  108
# Batch interaction:  109
# Batch interaction:  110
# Batch interaction:  111
# Batch interaction:  112
# Batch interaction:  113
# Batch interaction:  114
# Batch interaction:  115
# Batch interaction:  116
# Batch interaction:  117
# Batch interaction:  118
# Batch interaction:  119
# Batch interaction:  120
# Batch interaction:  121
# Batch interaction:  122
# Batch interaction:  123
# Batch interaction:  124
# Batch interaction:  125
# Batch interaction:  126
# Batch interaction:  127
# Batch interaction:  128
# Batch interaction:  129
# Batch interaction:  130
# Batch interaction:  131
# Batch interaction:  132
# Batch interaction:  133
# Batch interaction:  134
# Batch interaction:  135
# Batch interaction:  136
# Batch interaction:  137
# Batch interaction:  138
# Batch interaction:  139
# Batch interaction:  140
# Batch interaction:  141
# Batch interaction:  142
# Batch interaction:  143
# Batch interaction:  144
# Batch interaction:  145
# Batch interaction:  146
# Batch interaction:  147
# Batch interaction:  148
# Batch interaction:  149
# Batch interaction:  150
# Batch interaction:  151
# Batch interaction:  152
# Batch interaction:  153
# Batch interaction:  154
# Batch interaction:  155
# Batch interaction:  156
# Batch interaction:  157
# Batch interaction:  158
# Batch interaction:  159
# Batch interaction:  160
# Batch interaction:  161
# Batch interaction:  162
# Batch interaction:  163
# Batch interaction:  164
# Batch interaction:  165
# Batch interaction:  166
# Batch interaction:  167
# Batch interaction:  168
# Batch interaction:  169
# Batch interaction:  170
# Batch interaction:  171
# Batch interaction:  172
# Batch interaction:  173
# Batch interaction:  174
# Batch interaction:  175
# Batch interaction:  176
# Batch interaction:  177
# Batch interaction:  178
# Batch interaction:  179
# Batch interaction:  180
# Batch interaction:  181
# Batch interaction:  182
# Batch interaction:  183
# Batch interaction:  184
# Batch interaction:  185
# Batch interaction:  186
# Batch interaction:  187
# Batch interaction:  188
# Batch interaction:  189
# Batch interaction:  190
# Batch interaction:  191
# Batch interaction:  192
# Batch interaction:  193
# Batch interaction:  194
# Batch interaction:  195
# Batch interaction:  196
# Batch interaction:  197
# Batch interaction:  198
# Batch interaction:  199
# Batch interaction:  200
# Training accuracy: tensor(0.8845)
# Batch interaction:  201
# Batch interaction:  202
# Batch interaction:  203
# Batch interaction:  204
# Batch interaction:  205
# Batch interaction:  206
# Batch interaction:  207
# Batch interaction:  208
# Batch interaction:  209
# Batch interaction:  210
# Batch interaction:  211
# Batch interaction:  212
# Batch interaction:  213
# Batch interaction:  214
# Batch interaction:  215
# Batch interaction:  216
# Batch interaction:  217
# Batch interaction:  218
# Batch interaction:  219
# Batch interaction:  220
# Batch interaction:  221
# Batch interaction:  222
# Batch interaction:  223
# Batch interaction:  224
# Batch interaction:  225
# Batch interaction:  226
# Batch interaction:  227
# Batch interaction:  228
# Batch interaction:  229
# Batch interaction:  230
# Batch interaction:  231
# Batch interaction:  232
# Batch interaction:  233
# Batch interaction:  234
# Batch interaction:  235
# Batch interaction:  236
# Batch interaction:  237
# Batch interaction:  238
# Batch interaction:  239
# Batch interaction:  240
# Batch interaction:  241
# Batch interaction:  242
# Batch interaction:  243
# Batch interaction:  244
# Batch interaction:  245
# Batch interaction:  246
# Batch interaction:  247
# Batch interaction:  248
# Batch interaction:  249
# Batch interaction:  250
# Batch interaction:  251
# Batch interaction:  252
# Batch interaction:  253
# Batch interaction:  254
# Batch interaction:  255
# Batch interaction:  256
# Batch interaction:  257
# Batch interaction:  258
# Batch interaction:  259
# Batch interaction:  260
# Batch interaction:  261
# Batch interaction:  262
# Batch interaction:  263
# Batch interaction:  264
# Batch interaction:  265
# Batch interaction:  266
# Batch interaction:  267
# Batch interaction:  268
# Batch interaction:  269
# Batch interaction:  270
# Batch interaction:  271
# Batch interaction:  272
# Batch interaction:  273
# Batch interaction:  274
# Batch interaction:  275
# Batch interaction:  276
# Batch interaction:  277
# Batch interaction:  278
# Batch interaction:  279
# Batch interaction:  280
# Batch interaction:  281
# Batch interaction:  282
# Batch interaction:  283
# Batch interaction:  284
# Batch interaction:  285
# Batch interaction:  286
# Batch interaction:  287
# Batch interaction:  288
# Batch interaction:  289
# Batch interaction:  290
# Batch interaction:  291
# Batch interaction:  292
# Batch interaction:  293
# Batch interaction:  294
# Batch interaction:  295
# Batch interaction:  296
# Batch interaction:  297
# Batch interaction:  298
# Batch interaction:  299
# Batch interaction:  300
# Training accuracy: tensor(0.8876)
# Batch interaction:  301
# Batch interaction:  302
# Batch interaction:  303
# Batch interaction:  304
# Batch interaction:  305
# Batch interaction:  306
# Batch interaction:  307
# Batch interaction:  308
# Batch interaction:  309
# Batch interaction:  310
# Batch interaction:  311
# Batch interaction:  312
# Batch interaction:  313
# Batch interaction:  314
# Batch interaction:  315
# Batch interaction:  316
# Batch interaction:  317
# Batch interaction:  318
# Batch interaction:  319
# Batch interaction:  320
# Batch interaction:  321
# Batch interaction:  322
# Batch interaction:  323
# Batch interaction:  324
# Batch interaction:  325
# Batch interaction:  326
# Batch interaction:  327
# Batch interaction:  328
# Batch interaction:  329
# Batch interaction:  330
# Batch interaction:  331
# Batch interaction:  332
# Batch interaction:  333
# Batch interaction:  334
# Batch interaction:  335
# Batch interaction:  336
# Batch interaction:  337
# Batch interaction:  338
# Batch interaction:  339
# Batch interaction:  340
# Batch interaction:  341
# Batch interaction:  342
# Batch interaction:  343
# Batch interaction:  344
# Batch interaction:  345
# Batch interaction:  346
# Batch interaction:  347
# Batch interaction:  348
# Batch interaction:  349
# Batch interaction:  350
# Batch interaction:  351
# Batch interaction:  352
# Batch interaction:  353
# Batch interaction:  354
# Batch interaction:  355
# Batch interaction:  356
# Batch interaction:  357
# Batch interaction:  358
# Batch interaction:  359
# Batch interaction:  360
# Batch interaction:  361
# Batch interaction:  362
# Batch interaction:  363
# Batch interaction:  364
# Batch interaction:  365
# Batch interaction:  366
# Batch interaction:  367
# Batch interaction:  368
# Batch interaction:  369
# Batch interaction:  370
# Batch interaction:  371
# Batch interaction:  372
# Batch interaction:  373
# Batch interaction:  374
# Batch interaction:  375
# Batch interaction:  376
# Batch interaction:  377
# Batch interaction:  378
# Batch interaction:  379
# Batch interaction:  380
# Batch interaction:  381
# Batch interaction:  382
# Batch interaction:  383
# Batch interaction:  384
# Batch interaction:  385
# Batch interaction:  386
# Batch interaction:  387
# Batch interaction:  388
# Batch interaction:  389
# Batch interaction:  390
# Batch interaction:  391
# Batch interaction:  392
# Batch interaction:  393
# Batch interaction:  394
# Batch interaction:  395
# Batch interaction:  396
# Batch interaction:  397
# Batch interaction:  398
# Batch interaction:  399
# Batch interaction:  400
# Training accuracy: tensor(0.8868)
# Batch interaction:  401
# Batch interaction:  402
# Batch interaction:  403
# Batch interaction:  404
# Batch interaction:  405
# Batch interaction:  406
# Batch interaction:  407
# Batch interaction:  408
# Batch interaction:  409
# Batch interaction:  410
# Batch interaction:  411
# Batch interaction:  412
# Batch interaction:  413
# Batch interaction:  414
# Batch interaction:  415
# Batch interaction:  416
# Batch interaction:  417
# Batch interaction:  418
# Batch interaction:  419
# Batch interaction:  420
# Batch interaction:  421
# Batch interaction:  422
# Batch interaction:  423
# Batch interaction:  424
# Batch interaction:  425
# Batch interaction:  426
# Batch interaction:  427
# Batch interaction:  428
# Batch interaction:  429
# Batch interaction:  430
# Batch interaction:  431
# Batch interaction:  432
# Batch interaction:  433
# Batch interaction:  434
# Batch interaction:  435
# Batch interaction:  436
# Batch interaction:  437
# Batch interaction:  438
# Batch interaction:  439
# Batch interaction:  440
# Batch interaction:  441
# Batch interaction:  442
# Batch interaction:  443
# Batch interaction:  444
# Batch interaction:  445
# Batch interaction:  446
# Batch interaction:  447
# Batch interaction:  448
# Batch interaction:  449
# Batch interaction:  450
# Batch interaction:  451
# Batch interaction:  452
# Batch interaction:  453
# Batch interaction:  454
# Batch interaction:  455
# Batch interaction:  456
# Batch interaction:  457
# Batch interaction:  458
# Batch interaction:  459
# Batch interaction:  460
# Batch interaction:  461
# Batch interaction:  462
# Batch interaction:  463
# Batch interaction:  464
# Batch interaction:  465
# Batch interaction:  466
# Batch interaction:  467
# Batch interaction:  468
# Batch interaction:  469
# Batch interaction:  470
# Batch interaction:  471
# Batch interaction:  472
# Batch interaction:  473
# Batch interaction:  474
# Batch interaction:  475
# Batch interaction:  476
# Batch interaction:  477
# Batch interaction:  478
# Batch interaction:  479
# Batch interaction:  480
# Batch interaction:  481
# Batch interaction:  482
# Batch interaction:  483
# Batch interaction:  484
# Batch interaction:  485
# Batch interaction:  486
# Batch interaction:  487
# Batch interaction:  488
# Batch interaction:  489
# Batch interaction:  490
# Batch interaction:  491
# Batch interaction:  492
# Batch interaction:  493
# Batch interaction:  494
# Batch interaction:  495
# Batch interaction:  496
# Batch interaction:  497
# Batch interaction:  498
# Batch interaction:  499
# Batch interaction:  500
# Training accuracy: tensor(0.8858)
# Batch interaction:  501
# Batch interaction:  502
# Batch interaction:  503
# Batch interaction:  504
# Batch interaction:  505
# Batch interaction:  506
# Batch interaction:  507
# Batch interaction:  508
# Batch interaction:  509
# Batch interaction:  510
# Batch interaction:  511
# Batch interaction:  512
# Batch interaction:  513
# Batch interaction:  514
# Batch interaction:  515
# Batch interaction:  516
# Batch interaction:  517
# Batch interaction:  518
# Batch interaction:  519
# Batch interaction:  520
# Batch interaction:  521
# Batch interaction:  522
# Batch interaction:  523
# Batch interaction:  524
# Batch interaction:  525
# Batch interaction:  526
# Batch interaction:  527
# Batch interaction:  528
# Batch interaction:  529
# Batch interaction:  530
# Batch interaction:  531
# Batch interaction:  532
# Batch interaction:  533
# Batch interaction:  534
# Batch interaction:  535
# Batch interaction:  536
# Batch interaction:  537
# Batch interaction:  538
# Batch interaction:  539
# Batch interaction:  540
# Batch interaction:  541
# Batch interaction:  542
# Batch interaction:  543
# Batch interaction:  544
# Batch interaction:  545
# Batch interaction:  546
# Batch interaction:  547
# Batch interaction:  548
# Batch interaction:  549
# Batch interaction:  550
# Batch interaction:  551
# Batch interaction:  552
# Batch interaction:  553
# Batch interaction:  554
# Batch interaction:  555
# Batch interaction:  556
# Batch interaction:  557
# Batch interaction:  558
# Batch interaction:  559
# Batch interaction:  560
# Batch interaction:  561
# Batch interaction:  562
# Batch interaction:  563
# Batch interaction:  564
# Batch interaction:  565
# Batch interaction:  566
# Batch interaction:  567
# Batch interaction:  568
# Batch interaction:  569
# Batch interaction:  570
# Batch interaction:  571
# Batch interaction:  572
# Batch interaction:  573
# Batch interaction:  574
# Batch interaction:  575
# Batch interaction:  576
# Batch interaction:  577
# Batch interaction:  578
# Batch interaction:  579
# Batch interaction:  580
# Batch interaction:  581
# Batch interaction:  582
# Batch interaction:  583
# Batch interaction:  584
# Batch interaction:  585
# Batch interaction:  586
# Batch interaction:  587
# Batch interaction:  588
# Batch interaction:  589
# Batch interaction:  590
# Batch interaction:  591
# Batch interaction:  592
# Batch interaction:  593
# Batch interaction:  594
# Batch interaction:  595
# Batch interaction:  596
# Batch interaction:  597
# Batch interaction:  598
# Batch interaction:  599
# Batch interaction:  600
# Training accuracy: tensor(0.8851)
# Batch interaction:  601
# Batch interaction:  602
# Batch interaction:  603
# Batch interaction:  604
# Batch interaction:  605
# Batch interaction:  606
# Batch interaction:  607
# Batch interaction:  608
# Batch interaction:  609
# Batch interaction:  610
# Batch interaction:  611
# Batch interaction:  612
# Batch interaction:  613
# Batch interaction:  614
# Batch interaction:  615
# Batch interaction:  616
# Batch interaction:  617
# Batch interaction:  618
# Batch interaction:  619
# Batch interaction:  620
# Batch interaction:  621
# Batch interaction:  622
# Batch interaction:  623
# Batch interaction:  624
# Batch interaction:  625
# Batch interaction:  626
# Batch interaction:  627
# Batch interaction:  628
# Batch interaction:  629
# Batch interaction:  630
# Batch interaction:  631
# Batch interaction:  632
# Batch interaction:  633
# Batch interaction:  634
# Batch interaction:  635
# Batch interaction:  636
# Batch interaction:  637
# Batch interaction:  638
# Batch interaction:  639
# Batch interaction:  640
# Batch interaction:  641
# Batch interaction:  642
# Batch interaction:  643
# Batch interaction:  644
# Batch interaction:  645
# Batch interaction:  646
# Batch interaction:  647
# Batch interaction:  648
# Batch interaction:  649
# Batch interaction:  650
# Batch interaction:  651
# Batch interaction:  652
# Batch interaction:  653
# Batch interaction:  654
# Batch interaction:  655
# Batch interaction:  656
# Batch interaction:  657
# Batch interaction:  658
# Batch interaction:  659
# Batch interaction:  660
# Batch interaction:  661
# Batch interaction:  662
# Batch interaction:  663
# Batch interaction:  664
# Batch interaction:  665
# Batch interaction:  666
# Batch interaction:  667
# Batch interaction:  668
# Batch interaction:  669
# Batch interaction:  670
# Batch interaction:  671
# Batch interaction:  672
# Batch interaction:  673
# Batch interaction:  674
# Batch interaction:  675
# Batch interaction:  676
# Batch interaction:  677
# Batch interaction:  678
# Batch interaction:  679
# Batch interaction:  680
# Batch interaction:  681
# Batch interaction:  682
# Batch interaction:  683
# Batch interaction:  684
# Batch interaction:  685
# Batch interaction:  686
# Batch interaction:  687
# Batch interaction:  688
# Batch interaction:  689
# Batch interaction:  690
# Batch interaction:  691
# Batch interaction:  692
# Batch interaction:  693
# Batch interaction:  694
# Batch interaction:  695
# Batch interaction:  696
# Batch interaction:  697
# Batch interaction:  698
# Batch interaction:  699
# Batch interaction:  700
# Training accuracy: tensor(0.8852)
# Batch interaction:  701
# Batch interaction:  702
# Batch interaction:  703
# Batch interaction:  704
# Batch interaction:  705
# Batch interaction:  706
# Batch interaction:  707
# Batch interaction:  708
# Batch interaction:  709
# Batch interaction:  710
# Batch interaction:  711
# Batch interaction:  712
# Batch interaction:  713
# Batch interaction:  714
# Batch interaction:  715
# Batch interaction:  716
# Batch interaction:  717
# Batch interaction:  718
# Batch interaction:  719
# Batch interaction:  720
# Batch interaction:  721
# Batch interaction:  722
# Batch interaction:  723
# Batch interaction:  724
# Batch interaction:  725
# Batch interaction:  726
# Batch interaction:  727
# Batch interaction:  728
# Batch interaction:  729
# Batch interaction:  730
# Batch interaction:  731
# Batch interaction:  732
# Batch interaction:  733
# Batch interaction:  734
# Batch interaction:  735
# Batch interaction:  736
# Batch interaction:  737
# Batch interaction:  738
# Batch interaction:  739
# Batch interaction:  740
# Batch interaction:  741
# Batch interaction:  742
# Batch interaction:  743
# Batch interaction:  744
# Batch interaction:  745
# Batch interaction:  746
# Batch interaction:  747
# Batch interaction:  748
# Batch interaction:  749
# Batch interaction:  750
# Batch interaction:  751
# Batch interaction:  752
# Batch interaction:  753
# Batch interaction:  754
# Batch interaction:  755
# Batch interaction:  756
# Batch interaction:  757
# Batch interaction:  758
# Batch interaction:  759
# Batch interaction:  760
# Batch interaction:  761
# Batch interaction:  762
# Batch interaction:  763
# Batch interaction:  764
# Batch interaction:  765
# Batch interaction:  766
# Batch interaction:  767
# Batch interaction:  768
# Batch interaction:  769
# Batch interaction:  770
# Batch interaction:  771
# Batch interaction:  772
# Batch interaction:  773
# Batch interaction:  774
# Batch interaction:  775
# Batch interaction:  776
# Batch interaction:  777
# Batch interaction:  778
# Batch interaction:  779
# Batch interaction:  780
# Batch interaction:  781
# Batch interaction:  782
# Batch interaction:  783
# Batch interaction:  784
# Batch interaction:  785
# Batch interaction:  786
# Batch interaction:  787
# Batch interaction:  788
# Batch interaction:  789
# Batch interaction:  790
# Batch interaction:  791
# Batch interaction:  792
# Batch interaction:  793
# Batch interaction:  794
# Batch interaction:  795
# Batch interaction:  796
# Batch interaction:  797
# Batch interaction:  798
# Batch interaction:  799
# Batch interaction:  800
# Training accuracy: tensor(0.8852)
# Batch interaction:  801
# Batch interaction:  802
# Batch interaction:  803
# Batch interaction:  804
# Batch interaction:  805
# Batch interaction:  806
# Batch interaction:  807
# Batch interaction:  808
# Batch interaction:  809
# Batch interaction:  810
# Batch interaction:  811
# Batch interaction:  812
# Batch interaction:  813
# Batch interaction:  814
# Batch interaction:  815
# Batch interaction:  816
# Batch interaction:  817
# Batch interaction:  818
# Batch interaction:  819
# Batch interaction:  820
# Batch interaction:  821
# Batch interaction:  822
# Batch interaction:  823
# Batch interaction:  824
# Batch interaction:  825
# Batch interaction:  826
# Batch interaction:  827
# Batch interaction:  828
# Batch interaction:  829
# Batch interaction:  830
# Batch interaction:  831
# Batch interaction:  832
# Batch interaction:  833
# Batch interaction:  834
# Batch interaction:  835
# Batch interaction:  836
# Batch interaction:  837
# Batch interaction:  838
# Batch interaction:  839
# Batch interaction:  840
# Batch interaction:  841
# Batch interaction:  842
# Batch interaction:  843
# Batch interaction:  844
# Batch interaction:  845
# Batch interaction:  846
# Batch interaction:  847
# Batch interaction:  848
# Batch interaction:  849
# Batch interaction:  850
# Batch interaction:  851
# Batch interaction:  852
# Batch interaction:  853
# Batch interaction:  854
# Batch interaction:  855
# Batch interaction:  856
# Batch interaction:  857
# Batch interaction:  858
# Batch interaction:  859
# Batch interaction:  860
# Batch interaction:  861
# Batch interaction:  862
# Batch interaction:  863
# Batch interaction:  864
# Batch interaction:  865
# Batch interaction:  866
# Batch interaction:  867
# Batch interaction:  868
# Batch interaction:  869
# Batch interaction:  870
# Batch interaction:  871
# Batch interaction:  872
# Batch interaction:  873
# Batch interaction:  874
# Batch interaction:  875
# Batch interaction:  876
# Batch interaction:  877
# Batch interaction:  878
# Batch interaction:  879
# Batch interaction:  880
# Batch interaction:  881
# Batch interaction:  882
# Batch interaction:  883
# Batch interaction:  884
# Batch interaction:  885
# Batch interaction:  886
# Batch interaction:  887
# Batch interaction:  888
# Batch interaction:  889
# Batch interaction:  890
# Batch interaction:  891
# Batch interaction:  892
# Batch interaction:  893
# Batch interaction:  894
# Batch interaction:  895
# Batch interaction:  896
# Batch interaction:  897
# Batch interaction:  898
# Batch interaction:  899
# Batch interaction:  900
# Training accuracy: tensor(0.8846)
# Batch interaction:  901
# Batch interaction:  902
# Batch interaction:  903
# Batch interaction:  904
# Batch interaction:  905
# Batch interaction:  906
# Batch interaction:  907
# Batch interaction:  908
# Batch interaction:  909
# Batch interaction:  910
# Batch interaction:  911
# Batch interaction:  912
# Batch interaction:  913
# Batch interaction:  914
# Batch interaction:  915
# Batch interaction:  916
# Batch interaction:  917
# Batch interaction:  918
# Batch interaction:  919
# Batch interaction:  920
# Batch interaction:  921
# Batch interaction:  922
# Batch interaction:  923
# Batch interaction:  924
# Batch interaction:  925
# Batch interaction:  926
# Batch interaction:  927
# Batch interaction:  928
# Batch interaction:  929
# Batch interaction:  930
# Batch interaction:  931
# Batch interaction:  932
# Batch interaction:  933
# Batch interaction:  934
# Batch interaction:  935
# Batch interaction:  936
# Batch interaction:  937
# Batch interaction:  938
# Batch interaction:  939
# Batch interaction:  940
# Batch interaction:  941
# Batch interaction:  942
# Batch interaction:  943
# Batch interaction:  944
# Batch interaction:  945
# Batch interaction:  946
# Batch interaction:  947
# Batch interaction:  948
# Batch interaction:  949
# Batch interaction:  950
# Batch interaction:  951
# Batch interaction:  952
# Batch interaction:  953
# Batch interaction:  954
# Batch interaction:  955
# Batch interaction:  956
# Batch interaction:  957
# Batch interaction:  958
# Batch interaction:  959
# Batch interaction:  960
# Batch interaction:  961
# Batch interaction:  962
# Batch interaction:  963
# Batch interaction:  964
# Batch interaction:  965
# Batch interaction:  966
# Batch interaction:  967
# Batch interaction:  968
# Batch interaction:  969
# Batch interaction:  970
# Batch interaction:  971
# Batch interaction:  972
# Batch interaction:  973
# Batch interaction:  974
# Batch interaction:  975
# Batch interaction:  976
# Batch interaction:  977
# Batch interaction:  978
# Batch interaction:  979
# Batch interaction:  980
# Batch interaction:  981
# Batch interaction:  982
# Batch interaction:  983
# Batch interaction:  984
# Batch interaction:  985
# Batch interaction:  986
# Batch interaction:  987
# Batch interaction:  988
# Batch interaction:  989
# Batch interaction:  990
# Batch interaction:  991
# Batch interaction:  992
# Batch interaction:  993
# Batch interaction:  994
# Batch interaction:  995
# Batch interaction:  996
# Batch interaction:  997
# Batch interaction:  998
# Batch interaction:  999
# Batch interaction:  1000
# Training accuracy: tensor(0.8853)
# Batch interaction:  1001
# Batch interaction:  1002
# Batch interaction:  1003
# Batch interaction:  1004
# Batch interaction:  1005
# Batch interaction:  1006
# Batch interaction:  1007
# Batch interaction:  1008
# Batch interaction:  1009
# Batch interaction:  1010
# Batch interaction:  1011
# Batch interaction:  1012
# Batch interaction:  1013
# Batch interaction:  1014
# Batch interaction:  1015
# Batch interaction:  1016
# Batch interaction:  1017
# Batch interaction:  1018
# Batch interaction:  1019
# Batch interaction:  1020
# Batch interaction:  1021
# Batch interaction:  1022
# Batch interaction:  1023
# Batch interaction:  1024
# Batch interaction:  1025
# Batch interaction:  1026
# Batch interaction:  1027
# Batch interaction:  1028
# Batch interaction:  1029
# Batch interaction:  1030
# Batch interaction:  1031
# Batch interaction:  1032
# Batch interaction:  1033
# Batch interaction:  1034
# Batch interaction:  1035
# Batch interaction:  1036
# Batch interaction:  1037
# Batch interaction:  1038
# Batch interaction:  1039
# Batch interaction:  1040
# Batch interaction:  1041
# Batch interaction:  1042
# Batch interaction:  1043
# Batch interaction:  1044
# Batch interaction:  1045
# Batch interaction:  1046
# Batch interaction:  1047
# Batch interaction:  1048
# Batch interaction:  1049
# Batch interaction:  1050
# Batch interaction:  1051
# Batch interaction:  1052
# Batch interaction:  1053
# Batch interaction:  1054
# Batch interaction:  1055
# Batch interaction:  1056
# Batch interaction:  1057
# Batch interaction:  1058
# Batch interaction:  1059
# Batch interaction:  1060
# Batch interaction:  1061
# Batch interaction:  1062
# Batch interaction:  1063
# Batch interaction:  1064
# Batch interaction:  1065
# Batch interaction:  1066
# Batch interaction:  1067
# Batch interaction:  1068
# Batch interaction:  1069
# Batch interaction:  1070
# Batch interaction:  1071
# Batch interaction:  1072
# Batch interaction:  1073
# Batch interaction:  1074
# Batch interaction:  1075
# Batch interaction:  1076
# Batch interaction:  1077
# Batch interaction:  1078
# Batch interaction:  1079
# Batch interaction:  1080
# Batch interaction:  1081
# Batch interaction:  1082
# Batch interaction:  1083
# Batch interaction:  1084
# Batch interaction:  1085
# Batch interaction:  1086
# Batch interaction:  1087
# Batch interaction:  1088
# Batch interaction:  1089
# Batch interaction:  1090
# Batch interaction:  1091
# Batch interaction:  1092
# Batch interaction:  1093
# Batch interaction:  1094
# Batch interaction:  1095
# Batch interaction:  1096
# Batch interaction:  1097
# Batch interaction:  1098
# Batch interaction:  1099
# Batch interaction:  1100
# Training accuracy: tensor(0.8853)
# Batch interaction:  1101
# Batch interaction:  1102
# Batch interaction:  1103
# Batch interaction:  1104
# Batch interaction:  1105
# Batch interaction:  1106
# Batch interaction:  1107
# Batch interaction:  1108
# Batch interaction:  1109
# Batch interaction:  1110
# Batch interaction:  1111
# Batch interaction:  1112
# Batch interaction:  1113
# Batch interaction:  1114
# Batch interaction:  1115
# Batch interaction:  1116
# Batch interaction:  1117
# Batch interaction:  1118
# Batch interaction:  1119
# Batch interaction:  1120
# Batch interaction:  1121
# Batch interaction:  1122
# Batch interaction:  1123
# Batch interaction:  1124
# Batch interaction:  1125
# Batch interaction:  1126
# Batch interaction:  1127
# Batch interaction:  1128
# Batch interaction:  1129
# Batch interaction:  1130
# Batch interaction:  1131
# Batch interaction:  1132
# Batch interaction:  1133
# Batch interaction:  1134
# Batch interaction:  1135
# Batch interaction:  1136
# Batch interaction:  1137
# Batch interaction:  1138
# Batch interaction:  1139
# Batch interaction:  1140
# Batch interaction:  1141
# Batch interaction:  1142
# Batch interaction:  1143
# Batch interaction:  1144
# Batch interaction:  1145
# Batch interaction:  1146
# Batch interaction:  1147
# Batch interaction:  1148
# Batch interaction:  1149
# Batch interaction:  1150
# Batch interaction:  1151
# Batch interaction:  1152
# Batch interaction:  1153
# Batch interaction:  1154
# Batch interaction:  1155
# Batch interaction:  1156
# Batch interaction:  1157
# Batch interaction:  1158
# Batch interaction:  1159
# Batch interaction:  1160
# Batch interaction:  1161
# Batch interaction:  1162
# Batch interaction:  1163
# Batch interaction:  1164
# Batch interaction:  1165
# Batch interaction:  1166
# Batch interaction:  1167
# Batch interaction:  1168
# Batch interaction:  1169
# Batch interaction:  1170
# Batch interaction:  1171
# Batch interaction:  1172
# Batch interaction:  1173
# Batch interaction:  1174
# Batch interaction:  1175
# Batch interaction:  1176
# Batch interaction:  1177
# Batch interaction:  1178
# Batch interaction:  1179
# Batch interaction:  1180
# Batch interaction:  1181
# Batch interaction:  1182
# Batch interaction:  1183
# Batch interaction:  1184
# Batch interaction:  1185
# Batch interaction:  1186
# Batch interaction:  1187
# Batch interaction:  1188
# Batch interaction:  1189
# Batch interaction:  1190
# Batch interaction:  1191
# Batch interaction:  1192
# Batch interaction:  1193
# Batch interaction:  1194
# Batch interaction:  1195
# Batch interaction:  1196
# Batch interaction:  1197
# Batch interaction:  1198
# Batch interaction:  1199
# Batch interaction:  1200
# Training accuracy: tensor(0.8858)
# Batch interaction:  1201
# Batch interaction:  1202
# Batch interaction:  1203
# Batch interaction:  1204
# Batch interaction:  1205
# Batch interaction:  1206
# Batch interaction:  1207
# Batch interaction:  1208
# Batch interaction:  1209
# Batch interaction:  1210
# Batch interaction:  1211
# Batch interaction:  1212
# Batch interaction:  1213
# Batch interaction:  1214
# Batch interaction:  1215
# Batch interaction:  1216
# Batch interaction:  1217
# Batch interaction:  1218
# Batch interaction:  1219
# Batch interaction:  1220
# Batch interaction:  1221
# Batch interaction:  1222
# Batch interaction:  1223
# Batch interaction:  1224
# Batch interaction:  1225
# Batch interaction:  1226
# Batch interaction:  1227
# Batch interaction:  1228
# Batch interaction:  1229
# Batch interaction:  1230
# Batch interaction:  1231
# Batch interaction:  1232
# Batch interaction:  1233
# Batch interaction:  1234
# Batch interaction:  1235
# Batch interaction:  1236
# Batch interaction:  1237
# Batch interaction:  1238
# Batch interaction:  1239
# Batch interaction:  1240
# Batch interaction:  1241
# Batch interaction:  1242
# Batch interaction:  1243
# Batch interaction:  1244
# Batch interaction:  1245
# Batch interaction:  1246
# Batch interaction:  1247
# Batch interaction:  1248
# Batch interaction:  1249
# Batch interaction:  1250
# Batch interaction:  1251
# Batch interaction:  1252
# Batch interaction:  1253
# Batch interaction:  1254
# Batch interaction:  1255
# Batch interaction:  1256
# Batch interaction:  1257
# Batch interaction:  1258
# Batch interaction:  1259
# Batch interaction:  1260
# Batch interaction:  1261
# Batch interaction:  1262
# Batch interaction:  1263
# Batch interaction:  1264
# Batch interaction:  1265
# Batch interaction:  1266
# Batch interaction:  1267
# Batch interaction:  1268
# Batch interaction:  1269
# Batch interaction:  1270
# Batch interaction:  1271
# Batch interaction:  1272
# Batch interaction:  1273
# Batch interaction:  1274
# Batch interaction:  1275
# Batch interaction:  1276
# Batch interaction:  1277
# Batch interaction:  1278
# Batch interaction:  1279
# Batch interaction:  1280
# Batch interaction:  1281
# Batch interaction:  1282
# Batch interaction:  1283
# Batch interaction:  1284
# Batch interaction:  1285
# Batch interaction:  1286
# Batch interaction:  1287
# Batch interaction:  1288
# Batch interaction:  1289
# Batch interaction:  1290
# Batch interaction:  1291
# Batch interaction:  1292
# Batch interaction:  1293
# Batch interaction:  1294
# Batch interaction:  1295
# Batch interaction:  1296
# Batch interaction:  1297
# Batch interaction:  1298
# Batch interaction:  1299
# Batch interaction:  1300
# Training accuracy: tensor(0.8857)
# Batch interaction:  1301
# Batch interaction:  1302
# Batch interaction:  1303
# Batch interaction:  1304
# Batch interaction:  1305
# Batch interaction:  1306
# Batch interaction:  1307
# Batch interaction:  1308
# Batch interaction:  1309
# Batch interaction:  1310
# Batch interaction:  1311
# Batch interaction:  1312
# Batch interaction:  1313
# Batch interaction:  1314
# Batch interaction:  1315
# Batch interaction:  1316
# Batch interaction:  1317
# Batch interaction:  1318
# Batch interaction:  1319
# Batch interaction:  1320
# Batch interaction:  1321
# Batch interaction:  1322
# Batch interaction:  1323
# Batch interaction:  1324
# Batch interaction:  1325
# Batch interaction:  1326
# Batch interaction:  1327
# Batch interaction:  1328
# Batch interaction:  1329
# Batch interaction:  1330
# Batch interaction:  1331
# Batch interaction:  1332
# Batch interaction:  1333
# Batch interaction:  1334
# Batch interaction:  1335
# Batch interaction:  1336
# Batch interaction:  1337
# Batch interaction:  1338
# Batch interaction:  1339
# Batch interaction:  1340
# Batch interaction:  1341
# Batch interaction:  1342
# Batch interaction:  1343
# Batch interaction:  1344
# Batch interaction:  1345
# Batch interaction:  1346
# Batch interaction:  1347
# Batch interaction:  1348
# Batch interaction:  1349
# Batch interaction:  1350
# Batch interaction:  1351
# Batch interaction:  1352
# Batch interaction:  1353
# Batch interaction:  1354
# Batch interaction:  1355
# Batch interaction:  1356
# Batch interaction:  1357
# Batch interaction:  1358
# Batch interaction:  1359
# Batch interaction:  1360
# Batch interaction:  1361
# Batch interaction:  1362
# Batch interaction:  1363
# Batch interaction:  1364
# Batch interaction:  1365
# Batch interaction:  1366
# Batch interaction:  1367
# Batch interaction:  1368
# Batch interaction:  1369
# Batch interaction:  1370
# Batch interaction:  1371
# Batch interaction:  1372
# Batch interaction:  1373
# Batch interaction:  1374
# Batch interaction:  1375
# Batch interaction:  1376
# Batch interaction:  1377
# Batch interaction:  1378
# Batch interaction:  1379
# Batch interaction:  1380
# Batch interaction:  1381
# Batch interaction:  1382
# Batch interaction:  1383
# Batch interaction:  1384
# Batch interaction:  1385
# Batch interaction:  1386
# Batch interaction:  1387
# Batch interaction:  1388
# Batch interaction:  1389
# Batch interaction:  1390
# Batch interaction:  1391
# Batch interaction:  1392
# Batch interaction:  1393
# Batch interaction:  1394
# Batch interaction:  1395
# Batch interaction:  1396
# Batch interaction:  1397
# Batch interaction:  1398
# Batch interaction:  1399
# Batch interaction:  1400
# Training accuracy: tensor(0.8851)
# Batch interaction:  1401
# Batch interaction:  1402
# Batch interaction:  1403
# Batch interaction:  1404
# Batch interaction:  1405
# Batch interaction:  1406
# Batch interaction:  1407
# Batch interaction:  1408
# Batch interaction:  1409
# Batch interaction:  1410
# Batch interaction:  1411
# Batch interaction:  1412
# Batch interaction:  1413
# Batch interaction:  1414
# Batch interaction:  1415
# Batch interaction:  1416
# Batch interaction:  1417
# Batch interaction:  1418
# Batch interaction:  1419
# Batch interaction:  1420
# Batch interaction:  1421
# Batch interaction:  1422
# Batch interaction:  1423
# Batch interaction:  1424
# Batch interaction:  1425
# Batch interaction:  1426
# Batch interaction:  1427
# Batch interaction:  1428
# Batch interaction:  1429
# Batch interaction:  1430
# Batch interaction:  1431
# Batch interaction:  1432
# Batch interaction:  1433
# Batch interaction:  1434
# Batch interaction:  1435
# Batch interaction:  1436
# Batch interaction:  1437
# Batch interaction:  1438
# Batch interaction:  1439
# Batch interaction:  1440
# Batch interaction:  1441
# Batch interaction:  1442
# Batch interaction:  1443
# Batch interaction:  1444
# Batch interaction:  1445
# Batch interaction:  1446
# Batch interaction:  1447
# Batch interaction:  1448
# Batch interaction:  1449
# Batch interaction:  1450
# Batch interaction:  1451
# Batch interaction:  1452
# Batch interaction:  1453
# Batch interaction:  1454
# Batch interaction:  1455
# Batch interaction:  1456
# Batch interaction:  1457
# Batch interaction:  1458
# Batch interaction:  1459
# Batch interaction:  1460
# Batch interaction:  1461
# Batch interaction:  1462
# Batch interaction:  1463
# Batch interaction:  1464
# Batch interaction:  1465
# Batch interaction:  1466
# Batch interaction:  1467
# Batch interaction:  1468
# Batch interaction:  1469
# Batch interaction:  1470
# Batch interaction:  1471
# Batch interaction:  1472
# Batch interaction:  1473
# Batch interaction:  1474
# Batch interaction:  1475
# Batch interaction:  1476
# Batch interaction:  1477
# Batch interaction:  1478
# Batch interaction:  1479
# Batch interaction:  1480
# Batch interaction:  1481
# Batch interaction:  1482
# Batch interaction:  1483
# Batch interaction:  1484
# Batch interaction:  1485
# Batch interaction:  1486
# Batch interaction:  1487
# Batch interaction:  1488
# Batch interaction:  1489
# Batch interaction:  1490
# Batch interaction:  1491
# Batch interaction:  1492
# Batch interaction:  1493
# Batch interaction:  1494
# Batch interaction:  1495
# Batch interaction:  1496
# Batch interaction:  1497
# Batch interaction:  1498
# Batch interaction:  1499
# Batch interaction:  1500
# Training accuracy: tensor(0.8853)
# Batch interaction:  1501
# Batch interaction:  1502
# Batch interaction:  1503
# Batch interaction:  1504
# Batch interaction:  1505
# Batch interaction:  1506
# Batch interaction:  1507
# Batch interaction:  1508
# Batch interaction:  1509
# Batch interaction:  1510
# Batch interaction:  1511
# Batch interaction:  1512
# Batch interaction:  1513
# Batch interaction:  1514
# Batch interaction:  1515
# Batch interaction:  1516
# Batch interaction:  1517
# Batch interaction:  1518
# Batch interaction:  1519
# Batch interaction:  1520
# Batch interaction:  1521
# Batch interaction:  1522
# Batch interaction:  1523
# Batch interaction:  1524
# Batch interaction:  1525
# Batch interaction:  1526
# Batch interaction:  1527
# Batch interaction:  1528
# Batch interaction:  1529
# Batch interaction:  1530
# Batch interaction:  1531
# Batch interaction:  1532
# Batch interaction:  1533
# Batch interaction:  1534
# Batch interaction:  1535
# Batch interaction:  1536
# Batch interaction:  1537
# Batch interaction:  1538
# Batch interaction:  1539
# Batch interaction:  1540
# Batch interaction:  1541
# Batch interaction:  1542
# Batch interaction:  1543
# Batch interaction:  1544
# Batch interaction:  1545
# Batch interaction:  1546
# Batch interaction:  1547
# Batch interaction:  1548
# Batch interaction:  1549
# Batch interaction:  1550
# Batch interaction:  1551
# Batch interaction:  1552
# Batch interaction:  1553
# Batch interaction:  1554
# Batch interaction:  1555
# Batch interaction:  1556
# Batch interaction:  1557
# Batch interaction:  1558
# Batch interaction:  1559
# Batch interaction:  1560
# Batch interaction:  1561
# Batch interaction:  1562
# Batch interaction:  1563
# Batch interaction:  1564
# Batch interaction:  1565
# Batch interaction:  1566
# Batch interaction:  1567
# Batch interaction:  1568
# Batch interaction:  1569
# Batch interaction:  1570
# Batch interaction:  1571
# Batch interaction:  1572
# Batch interaction:  1573
# Batch interaction:  1574
# Batch interaction:  1575
# Batch interaction:  1576
# Batch interaction:  1577
# Batch interaction:  1578
# Batch interaction:  1579
# Batch interaction:  1580
# Batch interaction:  1581
# Batch interaction:  1582
# Batch interaction:  1583
# Batch interaction:  1584
# Batch interaction:  1585
# Batch interaction:  1586
# Batch interaction:  1587
# Batch interaction:  1588
# Batch interaction:  1589
# Batch interaction:  1590
# Batch interaction:  1591
# Batch interaction:  1592
# Batch interaction:  1593
# Batch interaction:  1594
# Batch interaction:  1595
# Batch interaction:  1596
# Batch interaction:  1597
# Batch interaction:  1598
# Batch interaction:  1599
# Batch interaction:  1600
# Training accuracy: tensor(0.8859)
# Batch interaction:  1601
# Batch interaction:  1602
# Batch interaction:  1603
# Batch interaction:  1604
# Batch interaction:  1605
# Batch interaction:  1606
# Batch interaction:  1607
# Batch interaction:  1608
# Batch interaction:  1609
# Batch interaction:  1610
# Batch interaction:  1611
# Batch interaction:  1612
# Batch interaction:  1613
# Batch interaction:  1614
# Batch interaction:  1615
# Batch interaction:  1616
# Batch interaction:  1617
# Batch interaction:  1618
# Batch interaction:  1619
# Batch interaction:  1620
# Batch interaction:  1621
# Batch interaction:  1622
# Batch interaction:  1623
# Batch interaction:  1624
# Batch interaction:  1625
# Batch interaction:  1626
# Batch interaction:  1627
# Batch interaction:  1628
# Batch interaction:  1629
# Batch interaction:  1630
# Batch interaction:  1631
# Batch interaction:  1632
# Batch interaction:  1633
# Batch interaction:  1634
# Batch interaction:  1635
# Batch interaction:  1636
# Batch interaction:  1637
# Batch interaction:  1638
# Batch interaction:  1639
# Batch interaction:  1640
# Batch interaction:  1641
# Batch interaction:  1642
# Batch interaction:  1643
# Batch interaction:  1644
# Batch interaction:  1645
# Batch interaction:  1646
# Batch interaction:  1647
# Batch interaction:  1648
# Batch interaction:  1649
# Batch interaction:  1650
# Batch interaction:  1651
# Batch interaction:  1652
# Batch interaction:  1653
# Batch interaction:  1654
# Batch interaction:  1655
# Batch interaction:  1656
# Batch interaction:  1657
# Batch interaction:  1658
# Batch interaction:  1659
# Batch interaction:  1660
# Batch interaction:  1661
# Batch interaction:  1662
# Batch interaction:  1663
# Batch interaction:  1664
# Batch interaction:  1665
# Batch interaction:  1666
# Batch interaction:  1667
# Batch interaction:  1668
# Batch interaction:  1669
# Batch interaction:  1670
# Batch interaction:  1671
# Batch interaction:  1672
# Batch interaction:  1673
# Batch interaction:  1674
# Batch interaction:  1675
# Batch interaction:  1676
# Batch interaction:  1677
# Batch interaction:  1678
# Batch interaction:  1679
# Batch interaction:  1680
# Batch interaction:  1681
# Batch interaction:  1682
# Batch interaction:  1683
# Batch interaction:  1684
# Batch interaction:  1685
# Batch interaction:  1686
# Batch interaction:  1687
# Batch interaction:  1688
# Batch interaction:  1689
# Batch interaction:  1690
# Batch interaction:  1691
# Batch interaction:  1692
# Batch interaction:  1693
# Batch interaction:  1694
# Batch interaction:  1695
# Batch interaction:  1696
# Batch interaction:  1697
# Batch interaction:  1698
# Batch interaction:  1699
# Batch interaction:  1700
# Training accuracy: tensor(0.8865)
# Batch interaction:  1701
# Batch interaction:  1702
# Batch interaction:  1703
# Batch interaction:  1704
# Batch interaction:  1705
# Batch interaction:  1706
# Batch interaction:  1707
# Batch interaction:  1708
# Batch interaction:  1709
# Batch interaction:  1710
# Batch interaction:  1711
# Batch interaction:  1712
# Batch interaction:  1713
# Batch interaction:  1714
# Batch interaction:  1715
# Batch interaction:  1716
# Batch interaction:  1717
# Batch interaction:  1718
# Batch interaction:  1719
# Batch interaction:  1720
# Batch interaction:  1721
# Batch interaction:  1722
# Batch interaction:  1723
# Batch interaction:  1724
# Batch interaction:  1725
# Batch interaction:  1726
# Batch interaction:  1727
# Batch interaction:  1728
# Batch interaction:  1729
# Batch interaction:  1730
# Batch interaction:  1731
# Batch interaction:  1732
# Batch interaction:  1733
# Batch interaction:  1734
# Batch interaction:  1735
# Batch interaction:  1736
# Batch interaction:  1737
# Batch interaction:  1738
# Batch interaction:  1739
# Batch interaction:  1740
# Batch interaction:  1741
# Batch interaction:  1742
# Batch interaction:  1743
# Batch interaction:  1744
# Batch interaction:  1745
# Batch interaction:  1746
# Batch interaction:  1747
# Batch interaction:  1748
# Batch interaction:  1749
# Batch interaction:  1750
# Batch interaction:  1751
# Batch interaction:  1752
# Batch interaction:  1753
# Batch interaction:  1754
# Batch interaction:  1755
# Batch interaction:  1756
# Batch interaction:  1757
# Batch interaction:  1758
# Batch interaction:  1759
# Batch interaction:  1760
# Batch interaction:  1761
# Batch interaction:  1762
# Batch interaction:  1763
# Batch interaction:  1764
# Batch interaction:  1765
# Batch interaction:  1766
# Batch interaction:  1767
# Batch interaction:  1768
# Batch interaction:  1769
# Batch interaction:  1770
# Batch interaction:  1771
# Batch interaction:  1772
# Batch interaction:  1773
# Batch interaction:  1774
# Batch interaction:  1775
# Batch interaction:  1776
# Batch interaction:  1777
# Batch interaction:  1778
# Batch interaction:  1779
# Batch interaction:  1780
# Batch interaction:  1781
# Batch interaction:  1782
# Batch interaction:  1783
# Batch interaction:  1784
# Batch interaction:  1785
# Batch interaction:  1786
# Batch interaction:  1787
# Batch interaction:  1788
# Batch interaction:  1789
# Batch interaction:  1790
# Batch interaction:  1791
# Batch interaction:  1792
# Batch interaction:  1793
# Batch interaction:  1794
# Batch interaction:  1795
# Batch interaction:  1796
# Batch interaction:  1797
# Batch interaction:  1798
# Batch interaction:  1799
# Batch interaction:  1800
# Training accuracy: tensor(0.8867)
# Batch interaction:  1801
# Batch interaction:  1802
# Batch interaction:  1803
# Batch interaction:  1804
# Batch interaction:  1805
# Batch interaction:  1806
# Batch interaction:  1807
# Batch interaction:  1808
# Batch interaction:  1809
# Batch interaction:  1810
# Batch interaction:  1811
# Batch interaction:  1812
# Batch interaction:  1813
# Batch interaction:  1814
# Batch interaction:  1815
# Batch interaction:  1816
# Batch interaction:  1817
# Batch interaction:  1818
# Batch interaction:  1819
# Batch interaction:  1820
# Batch interaction:  1821
# Batch interaction:  1822
# Batch interaction:  1823
# Batch interaction:  1824
# Batch interaction:  1825
# Batch interaction:  1826
# Batch interaction:  1827
# Batch interaction:  1828
# Batch interaction:  1829
# Batch interaction:  1830
# Batch interaction:  1831
# Batch interaction:  1832
# Batch interaction:  1833
# Batch interaction:  1834
# Batch interaction:  1835
# Batch interaction:  1836
# Batch interaction:  1837
# Batch interaction:  1838
# Batch interaction:  1839
# Batch interaction:  1840
# Batch interaction:  1841
# Batch interaction:  1842
# Batch interaction:  1843
# Batch interaction:  1844
# Batch interaction:  1845
# Batch interaction:  1846
# Batch interaction:  1847
# Batch interaction:  1848
# Batch interaction:  1849
# Batch interaction:  1850
# Batch interaction:  1851
# Batch interaction:  1852
# Batch interaction:  1853
# Batch interaction:  1854
# Batch interaction:  1855
# Batch interaction:  1856
# Batch interaction:  1857
# Batch interaction:  1858
# Batch interaction:  1859
# Batch interaction:  1860
# Batch interaction:  1861
# Batch interaction:  1862
# Batch interaction:  1863
# Batch interaction:  1864
# Batch interaction:  1865
# Batch interaction:  1866
# Batch interaction:  1867
# Batch interaction:  1868
# Batch interaction:  1869
# Batch interaction:  1870
# Batch interaction:  1871
# Batch interaction:  1872
# Batch interaction:  1873
# Batch interaction:  1874
# Batch interaction:  1875
# Batch interaction:  1876
# Batch interaction:  1877
# Batch interaction:  1878
# Batch interaction:  1879
# Batch interaction:  1880
# Batch interaction:  1881
# Batch interaction:  1882
# Batch interaction:  1883
# Batch interaction:  1884
# Batch interaction:  1885
# Batch interaction:  1886
# Batch interaction:  1887
# Batch interaction:  1888
# Batch interaction:  1889
# Batch interaction:  1890
# Batch interaction:  1891
# Batch interaction:  1892
# Batch interaction:  1893
# Batch interaction:  1894
# Batch interaction:  1895
# Batch interaction:  1896
# Batch interaction:  1897
# Batch interaction:  1898
# Batch interaction:  1899
# Batch interaction:  1900
# Training accuracy: tensor(0.8869)
# Batch interaction:  1901
# Batch interaction:  1902
# Batch interaction:  1903
# Batch interaction:  1904
# Batch interaction:  1905
# Batch interaction:  1906
# Batch interaction:  1907
# Batch interaction:  1908
# Batch interaction:  1909
# Batch interaction:  1910
# Batch interaction:  1911
# Batch interaction:  1912
# Batch interaction:  1913
# Batch interaction:  1914
# Batch interaction:  1915
# Batch interaction:  1916
# Batch interaction:  1917
# Batch interaction:  1918
# Batch interaction:  1919
# Batch interaction:  1920
# Batch interaction:  1921
# Batch interaction:  1922
# Batch interaction:  1923
# Batch interaction:  1924
# Batch interaction:  1925
# Batch interaction:  1926
# Batch interaction:  1927
# Batch interaction:  1928
# Batch interaction:  1929
# Batch interaction:  1930
# Batch interaction:  1931
# Batch interaction:  1932
# Batch interaction:  1933
# Batch interaction:  1934
# Batch interaction:  1935
# Batch interaction:  1936
# Batch interaction:  1937
# Batch interaction:  1938
# ...
# Batch interaction:  8762
# Batch interaction:  8763
# Batch interaction:  8764
# Batch interaction:  8765
# Batch interaction:  8766
# Batch interaction:  8767
# Batch interaction:  8768
# Batch interaction:  8769
# Batch interaction:  8770
# Batch interaction:  8771
# Batch interaction:  8772
# Batch interaction:  8773
# Batch interaction:  8774
# Batch interaction:  8775
# Batch interaction:  8776
# Batch interaction:  8777
# Batch interaction:  8778
# Batch interaction:  8779
# Batch interaction:  8780
# Batch interaction:  8781
# Batch interaction:  8782
# Batch interaction:  8783
# Batch interaction:  8784
# Batch interaction:  8785
# Batch interaction:  8786
# Batch interaction:  8787
# Batch interaction:  8788
# Batch interaction:  8789
# Batch interaction:  8790
# Batch interaction:  8791
# Batch interaction:  8792
# Batch interaction:  8793
# Batch interaction:  8794
# Batch interaction:  8795
# Batch interaction:  8796
# Batch interaction:  8797
# Batch interaction:  8798
# Batch interaction:  8799
# Batch interaction:  8800
# Training accuracy: tensor(0.8921)
# Batch interaction:  8801
# Batch interaction:  8802
# Batch interaction:  8803
# Batch interaction:  8804
# Batch interaction:  8805
# Batch interaction:  8806
# Batch interaction:  8807
# Batch interaction:  8808
# Batch interaction:  8809
# Batch interaction:  8810
# Batch interaction:  8811
# Batch interaction:  8812
# Batch interaction:  8813
# Batch interaction:  8814
# Batch interaction:  8815
# Batch interaction:  8816
# Batch interaction:  8817
# Batch interaction:  8818
# Batch interaction:  8819
# Batch interaction:  8820
# Batch interaction:  8821
# Batch interaction:  8822
# Batch interaction:  8823
# Batch interaction:  8824
# Batch interaction:  8825
# Batch interaction:  8826
# Batch interaction:  8827
# Batch interaction:  8828
# Batch interaction:  8829
# Batch interaction:  8830
# Batch interaction:  8831
# Batch interaction:  8832
# Batch interaction:  8833
# Batch interaction:  8834
# Batch interaction:  8835
# Batch interaction:  8836
# Batch interaction:  8837
# Batch interaction:  8838
# Batch interaction:  8839
# Batch interaction:  8840
# Batch interaction:  8841
# Batch interaction:  8842
# Batch interaction:  8843
# Batch interaction:  8844
# Batch interaction:  8845
# Batch interaction:  8846
# Batch interaction:  8847
# Batch interaction:  8848
# Batch interaction:  8849
# Batch interaction:  8850
# Batch interaction:  8851
# Batch interaction:  8852
# Batch interaction:  8853
# Batch interaction:  8854
# Batch interaction:  8855
# Batch interaction:  8856
# Batch interaction:  8857
# Batch interaction:  8858
# Batch interaction:  8859
# Batch interaction:  8860
# Batch interaction:  8861
# Batch interaction:  8862
# Batch interaction:  8863
# Batch interaction:  8864
# Batch interaction:  8865
# Batch interaction:  8866
# Batch interaction:  8867
# Batch interaction:  8868
# Batch interaction:  8869
# Batch interaction:  8870
# Batch interaction:  8871
# Batch interaction:  8872
# Batch interaction:  8873
# Batch interaction:  8874
# Batch interaction:  8875
# Batch interaction:  8876
# Batch interaction:  8877
# Batch interaction:  8878
# Batch interaction:  8879
# Batch interaction:  8880
# Batch interaction:  8881
# Batch interaction:  8882
# Batch interaction:  8883
# Batch interaction:  8884
# Batch interaction:  8885
# Batch interaction:  8886
# Batch interaction:  8887
# Batch interaction:  8888
# Batch interaction:  8889
# Batch interaction:  8890
# Batch interaction:  8891
# Batch interaction:  8892
# Batch interaction:  8893
# Batch interaction:  8894
# Batch interaction:  8895
# Batch interaction:  8896
# Batch interaction:  8897
# Batch interaction:  8898
# Batch interaction:  8899
# Batch interaction:  8900
# Training accuracy: tensor(0.8921)
# Batch interaction:  8901
# Batch interaction:  8902
# Batch interaction:  8903
# Batch interaction:  8904
# Batch interaction:  8905
# Batch interaction:  8906
# Batch interaction:  8907
# Batch interaction:  8908
# Batch interaction:  8909
# Batch interaction:  8910
# Batch interaction:  8911
# Batch interaction:  8912
# Batch interaction:  8913
# Batch interaction:  8914
# Batch interaction:  8915
# Batch interaction:  8916
# Batch interaction:  8917
# Batch interaction:  8918
# Batch interaction:  8919
# Batch interaction:  8920
# Batch interaction:  8921
# Batch interaction:  8922
# Batch interaction:  8923
# Batch interaction:  8924
# Batch interaction:  8925
# Batch interaction:  8926
# Batch interaction:  8927
# Batch interaction:  8928
# Batch interaction:  8929
# Batch interaction:  8930
# Batch interaction:  8931
# Batch interaction:  8932
# Batch interaction:  8933
# Batch interaction:  8934
# Batch interaction:  8935
# Batch interaction:  8936
# Batch interaction:  8937
# Batch interaction:  8938
# Batch interaction:  8939
# Batch interaction:  8940
# Batch interaction:  8941
# Batch interaction:  8942
# Batch interaction:  8943
# Batch interaction:  8944
# Batch interaction:  8945
# Batch interaction:  8946
# Batch interaction:  8947
# Batch interaction:  8948
# Batch interaction:  8949
# Batch interaction:  8950
# Batch interaction:  8951
# Batch interaction:  8952
# Batch interaction:  8953
# Batch interaction:  8954
# Batch interaction:  8955
# Batch interaction:  8956
# Batch interaction:  8957
# Batch interaction:  8958
# Batch interaction:  8959
# Batch interaction:  8960
# Batch interaction:  8961
# Batch interaction:  8962
# Batch interaction:  8963
# Batch interaction:  8964
# Batch interaction:  8965
# Batch interaction:  8966
# Batch interaction:  8967
# Batch interaction:  8968
# Batch interaction:  8969
# Batch interaction:  8970
# Batch interaction:  8971
# Batch interaction:  8972
# Batch interaction:  8973
# Batch interaction:  8974
# Batch interaction:  8975
# Batch interaction:  8976
# Batch interaction:  8977
# Batch interaction:  8978
# Batch interaction:  8979
# Batch interaction:  8980
# Batch interaction:  8981
# Batch interaction:  8982
# Batch interaction:  8983
# Batch interaction:  8984
# Batch interaction:  8985
# Batch interaction:  8986
# Batch interaction:  8987
# Batch interaction:  8988
# Batch interaction:  8989
# Batch interaction:  8990
# Batch interaction:  8991
# Batch interaction:  8992
# Batch interaction:  8993
# Batch interaction:  8994
# Batch interaction:  8995
# Batch interaction:  8996
# Batch interaction:  8997
# Batch interaction:  8998
# Batch interaction:  8999
# Batch interaction:  9000
# Training accuracy: tensor(0.8922)
# Batch interaction:  9001
# Batch interaction:  9002
# Batch interaction:  9003
# Batch interaction:  9004
# Batch interaction:  9005
# Batch interaction:  9006
# Batch interaction:  9007
# Batch interaction:  9008
# Batch interaction:  9009
# Batch interaction:  9010
# Batch interaction:  9011
# Batch interaction:  9012
# Batch interaction:  9013
# Batch interaction:  9014
# Batch interaction:  9015
# Batch interaction:  9016
# Batch interaction:  9017
# Batch interaction:  9018
# Batch interaction:  9019
# Batch interaction:  9020
# Batch interaction:  9021
# Batch interaction:  9022
# Batch interaction:  9023
# Batch interaction:  9024
# Batch interaction:  9025
# Batch interaction:  9026
# Batch interaction:  9027
# Batch interaction:  9028
# Batch interaction:  9029
# Batch interaction:  9030
# Batch interaction:  9031
# Batch interaction:  9032
# Batch interaction:  9033
# Batch interaction:  9034
# Batch interaction:  9035
# Batch interaction:  9036
# Batch interaction:  9037
# Batch interaction:  9038
# Batch interaction:  9039
# Batch interaction:  9040
# Batch interaction:  9041
# Batch interaction:  9042
# Batch interaction:  9043
# Batch interaction:  9044
# Batch interaction:  9045
# Batch interaction:  9046
# Batch interaction:  9047
# Batch interaction:  9048
# Batch interaction:  9049
# Batch interaction:  9050
# Batch interaction:  9051
# Batch interaction:  9052
# Batch interaction:  9053
# Batch interaction:  9054
# Batch interaction:  9055
# Batch interaction:  9056
# Batch interaction:  9057
# Batch interaction:  9058
# Batch interaction:  9059
# Batch interaction:  9060
# Batch interaction:  9061
# Batch interaction:  9062
# Batch interaction:  9063
# Batch interaction:  9064
# Batch interaction:  9065
# Batch interaction:  9066
# Batch interaction:  9067
# Batch interaction:  9068
# Batch interaction:  9069
# Batch interaction:  9070
# Batch interaction:  9071
# Batch interaction:  9072
# Batch interaction:  9073
# Batch interaction:  9074
# Batch interaction:  9075
# Batch interaction:  9076
# Batch interaction:  9077
# Batch interaction:  9078
# Batch interaction:  9079
# Batch interaction:  9080
# Batch interaction:  9081
# Batch interaction:  9082
# Batch interaction:  9083
# Batch interaction:  9084
# Batch interaction:  9085
# Batch interaction:  9086
# Batch interaction:  9087
# Batch interaction:  9088
# Batch interaction:  9089
# Batch interaction:  9090
# Batch interaction:  9091
# Batch interaction:  9092
# Batch interaction:  9093
# Batch interaction:  9094
# Batch interaction:  9095
# Batch interaction:  9096
# Batch interaction:  9097
# Batch interaction:  9098
# Batch interaction:  9099
# Batch interaction:  9100
# Training accuracy: tensor(0.8922)
# Batch interaction:  9101
# Batch interaction:  9102
# Batch interaction:  9103
# Batch interaction:  9104
# Batch interaction:  9105
# Batch interaction:  9106
# Batch interaction:  9107
# Batch interaction:  9108
# Batch interaction:  9109
# Batch interaction:  9110
# Batch interaction:  9111
# Batch interaction:  9112
# Batch interaction:  9113
# Batch interaction:  9114
# Batch interaction:  9115
# Batch interaction:  9116
# Batch interaction:  9117
# Batch interaction:  9118
# Batch interaction:  9119
# Batch interaction:  9120
# Batch interaction:  9121
# Batch interaction:  9122
# Batch interaction:  9123
# Batch interaction:  9124
# Batch interaction:  9125
# Batch interaction:  9126
# Batch interaction:  9127
# Batch interaction:  9128
# Batch interaction:  9129
# Batch interaction:  9130
# Batch interaction:  9131
# Batch interaction:  9132
# Batch interaction:  9133
# Batch interaction:  9134
# Batch interaction:  9135
# Batch interaction:  9136
# Batch interaction:  9137
# Batch interaction:  9138
# Batch interaction:  9139
# Batch interaction:  9140
# Batch interaction:  9141
# Batch interaction:  9142
# Batch interaction:  9143
# Batch interaction:  9144
# Batch interaction:  9145
# Batch interaction:  9146
# Batch interaction:  9147
# Batch interaction:  9148
# Batch interaction:  9149
# Batch interaction:  9150
# Batch interaction:  9151
# Batch interaction:  9152
# Batch interaction:  9153
# Batch interaction:  9154
# Batch interaction:  9155
# Batch interaction:  9156
# Batch interaction:  9157
# Batch interaction:  9158
# Batch interaction:  9159
# Batch interaction:  9160
# Batch interaction:  9161
# Batch interaction:  9162
# Batch interaction:  9163
# Batch interaction:  9164
# Batch interaction:  9165
# Batch interaction:  9166
# Batch interaction:  9167
# Batch interaction:  9168
# Batch interaction:  9169
# Batch interaction:  9170
# Batch interaction:  9171
# Batch interaction:  9172
# Batch interaction:  9173
# Batch interaction:  9174
# Batch interaction:  9175
# Batch interaction:  9176
# Batch interaction:  9177
# Batch interaction:  9178
# Batch interaction:  9179
# Batch interaction:  9180
# Batch interaction:  9181
# Batch interaction:  9182
# Batch interaction:  9183
# Batch interaction:  9184
# Batch interaction:  9185
# Batch interaction:  9186
# Batch interaction:  9187
# Batch interaction:  9188
# Batch interaction:  9189
# Batch interaction:  9190
# Batch interaction:  9191
# Batch interaction:  9192
# Batch interaction:  9193
# Batch interaction:  9194
# Batch interaction:  9195
# Batch interaction:  9196
# Batch interaction:  9197
# Batch interaction:  9198
# Batch interaction:  9199
# Batch interaction:  9200
# Training accuracy: tensor(0.8922)
# Batch interaction:  9201
# Batch interaction:  9202
# Batch interaction:  9203
# Batch interaction:  9204
# Batch interaction:  9205
# Batch interaction:  9206
# Batch interaction:  9207
# Batch interaction:  9208
# Batch interaction:  9209
# Batch interaction:  9210
# Batch interaction:  9211
# Batch interaction:  9212
# Batch interaction:  9213
# Batch interaction:  9214
# Batch interaction:  9215
# Batch interaction:  9216
# Batch interaction:  9217
# Batch interaction:  9218
# Batch interaction:  9219
# Batch interaction:  9220
# Batch interaction:  9221
# Batch interaction:  9222
# Batch interaction:  9223
# Batch interaction:  9224
# Batch interaction:  9225
# Batch interaction:  9226
# Batch interaction:  9227
# Batch interaction:  9228
# Batch interaction:  9229
# Batch interaction:  9230
# Batch interaction:  9231
# Batch interaction:  9232
# Batch interaction:  9233
# Batch interaction:  9234
# Batch interaction:  9235
# Batch interaction:  9236
# Batch interaction:  9237
# Batch interaction:  9238
# Batch interaction:  9239
# Batch interaction:  9240
# Batch interaction:  9241
# Batch interaction:  9242
# Batch interaction:  9243
# Batch interaction:  9244
# Batch interaction:  9245
# Batch interaction:  9246
# Batch interaction:  9247
# Batch interaction:  9248
# Batch interaction:  9249
# Batch interaction:  9250
# Batch interaction:  9251
# Batch interaction:  9252
# Batch interaction:  9253
# Batch interaction:  9254
# Batch interaction:  9255
# Batch interaction:  9256
# Batch interaction:  9257
# Batch interaction:  9258
# Batch interaction:  9259
# Batch interaction:  9260
# Batch interaction:  9261
# Batch interaction:  9262
# Batch interaction:  9263
# Batch interaction:  9264
# Batch interaction:  9265
# Batch interaction:  9266
# Batch interaction:  9267
# Batch interaction:  9268
# Batch interaction:  9269
# Batch interaction:  9270
# Batch interaction:  9271
# Batch interaction:  9272
# Batch interaction:  9273
# Batch interaction:  9274
# Batch interaction:  9275
# Batch interaction:  9276
# Batch interaction:  9277
# Batch interaction:  9278
# Batch interaction:  9279
# Batch interaction:  9280
# Batch interaction:  9281
# Batch interaction:  9282
# Batch interaction:  9283
# Batch interaction:  9284
# Batch interaction:  9285
# Batch interaction:  9286
# Batch interaction:  9287
# Batch interaction:  9288
# Batch interaction:  9289
# Batch interaction:  9290
# Batch interaction:  9291
# Batch interaction:  9292
# Batch interaction:  9293
# Batch interaction:  9294
# Batch interaction:  9295
# Batch interaction:  9296
# Batch interaction:  9297
# Batch interaction:  9298
# Batch interaction:  9299
# Batch interaction:  9300
# Training accuracy: tensor(0.8923)
# Batch interaction:  9301
# Batch interaction:  9302
# Batch interaction:  9303
# Batch interaction:  9304
# Batch interaction:  9305
# Batch interaction:  9306
# Batch interaction:  9307
# Batch interaction:  9308
# Batch interaction:  9309
# Batch interaction:  9310
# Batch interaction:  9311
# Batch interaction:  9312
# Batch interaction:  9313
# Batch interaction:  9314
# Batch interaction:  9315
# Batch interaction:  9316
# Batch interaction:  9317
# Batch interaction:  9318
# Batch interaction:  9319
# Batch interaction:  9320
# Batch interaction:  9321
# Batch interaction:  9322
# Batch interaction:  9323
# Batch interaction:  9324
# Batch interaction:  9325
# Batch interaction:  9326
# Batch interaction:  9327
# Batch interaction:  9328
# Batch interaction:  9329
# Batch interaction:  9330
# Batch interaction:  9331
# Batch interaction:  9332
# Batch interaction:  9333
# Batch interaction:  9334
# Batch interaction:  9335
# Batch interaction:  9336
# Batch interaction:  9337
# Batch interaction:  9338
# Batch interaction:  9339
# Batch interaction:  9340
# Batch interaction:  9341
# Batch interaction:  9342
# Batch interaction:  9343
# Batch interaction:  9344
# Batch interaction:  9345
# Batch interaction:  9346
# Batch interaction:  9347
# Batch interaction:  9348
# Batch interaction:  9349
# Batch interaction:  9350
# Batch interaction:  9351
# Batch interaction:  9352
# Batch interaction:  9353
# Batch interaction:  9354
# Batch interaction:  9355
# Batch interaction:  9356
# Batch interaction:  9357
# Batch interaction:  9358
# Batch interaction:  9359
# Batch interaction:  9360
# Batch interaction:  9361
# Batch interaction:  9362
# Batch interaction:  9363
# Batch interaction:  9364
# Batch interaction:  9365
# Batch interaction:  9366
# Batch interaction:  9367
# Batch interaction:  9368
# Batch interaction:  9369
# Batch interaction:  9370
# Batch interaction:  9371
# Batch interaction:  9372
# Batch interaction:  9373
# Batch interaction:  9374
# Batch interaction:  9375
# Batch interaction:  9376
# Batch interaction:  9377
# Batch interaction:  9378
# Batch interaction:  9379
# Batch interaction:  9380
# Batch interaction:  9381
# Batch interaction:  9382
# Batch interaction:  9383
# Batch interaction:  9384
# Batch interaction:  9385
# Batch interaction:  9386
# Batch interaction:  9387
# Batch interaction:  9388
# Batch interaction:  9389
# Batch interaction:  9390
# Batch interaction:  9391
# Batch interaction:  9392

# %% [markdown]
# After each epoch we evaluate the model over the validation partition.

# %%
counter = 0

images_tensor = torch.zeros(60,3,560,560)
titles_tensor = torch.zeros(60,15)
labels_tensor = torch.zeros(60)
accuracy_valid = 0

# Validation pass

with torch.no_grad():
    
 for i in range(len(valid_images_final)):
    
    # First check if image is available
    
    img = cv2.imread(PATH + valid_images_final[i])
        
    if type(img) is not type(None):
        
        # Add 1 to counter
        
        counter += 1
               
        # Pad it with zeos to obtain 560 x 560 shape
        
        img_padded = pad_images(img)
        
        # Store image and corresponding title and label 
        images_tensor[counter-1, :,:,:] = torch.from_numpy(img_padded)
        titles_tensor[counter-1, :] = torch.from_numpy(valid_tokenized_pad[i]).int()
        labels_tensor[counter - 1] = valid_labels[i] 
         
        
        if counter%60 == 0:
            
           repetitions_valid += 1

           # Pass image and text through the different layers
            
           out = model_CNN_image_text.forward(images_tensor, titles_tensor.int())         
                 
           # Obtain number of correct predictions and store accuracy
            
           top_p, top_class = out.topk(1, dim=1) 
           equals = (top_class == labels_tensor.view(images_tensor.shape[0], 1))
           accuracy_valid += torch.mean(equals.type(torch.FloatTensor))
        
           images_tensor = torch.zeros(60,3,560,560)
           titles_tensor = torch.zeros(60,15)
           labels_tensor = torch.zeros(60)
            
           counter = 0 
           

print("Validation accuracy:", accuracy_valid/repetitions_valid)
# Out:
# Validation accuracy: tensor(0.8703)

# %% [markdown]
# The following table shows the accuracy that we have obtained for each number of epochs.
#
# | Epochs | Accuracy |
# |--------|----------|
# |   1    |  0.8635  |
# |   2    |  0.8707  |
# |   3    |  0.8703  |
#
# As we can see the highest accuracy is obtained when we train the model for **2** epochs so this is the number of epochs that we will use.

# %% [markdown]
# ## Testing performance
#
# ### Training with train + validation data
#
# We join the train and validation data and we train the model with it.

# %%
# Join train and validation sequences
train_valid_tokenized_pad = np.concatenate((train_tokenized_pad, valid_tokenized_pad), axis = 0)
# Join train and validation labels
train_valid_labels = train_labels + valid_labels
# Join images names
train_valid_images_final = train_images_final + valid_images_final

# %% [markdown]
# Train the model.

# %%
# Instantiate model
model_CNN_image_text_final = CNN_title_images(image_dimx = 560 ,nlabels = 6 )

# %% [markdown]
# The following cell has to be run 2 times, one for each epoch.

# %%
# Create counter to be used in the loop
counter = 0
# To count the number of batches
repetitions_train = 0
repetitions_valid = 0
# Error function
criterion = nn.NLLLoss()
# Optimizer
optimizer = torch.optim.Adam(model_CNN_image_text_final.parameters(), lr = 0.001)
# To store train accuracy
accuracy_train = 0
# To store valation accuracy
accuracy_valid = 0


images_tensor = torch.zeros(60,3,560,560)
titles_tensor = torch.zeros(60,15)
labels_tensor = torch.zeros(60)

for i in range(len(train_valid_images_final)):
    
    # First check if image is available
    img = cv2.imread(PATH + train_valid_images_final[i])   
        
    if type(img) is not type(None):
                          
        counter += 1
        
        # Pad it with zeros or truncate it to obtain 560 x 560 shape
        
        img_padded = pad_images(img)
        
        # Store image and corresponding title and label 
        images_tensor[counter-1, :,:,:] = torch.from_numpy(img_padded)
        titles_tensor[counter-1, :] = torch.from_numpy(train_valid_tokenized_pad[i]).int()
        labels_tensor[counter - 1] = train_valid_labels[i]    
        
        
        if counter%60 == 0:
            
           repetitions_train += 1
           print("Batch interaction: ", repetitions_train)

           # Reset gradients
           optimizer.zero_grad() 

           # Pass image and text through the different layers
            
           out = model_CNN_image_text_final.forward(images_tensor, titles_tensor.long())         
            
           # Compute loss
        
           loss = criterion(out,labels_tensor.long())
            
           # Backpropagation
           
           loss.backward()
        
           # Optimize parameters
            
           optimizer.step()
            
           # Obtain number of correct predictions and store accuracy
            
           top_p, top_class = out.topk(1, dim=1) 
           equals = (top_class == labels_tensor.view(images_tensor.shape[0], 1))
           accuracy_train += torch.mean(equals.type(torch.FloatTensor))
        
           images_tensor = torch.zeros(60,3,560,560)
           titles_tensor = torch.zeros(60,15)
           labels_tensor = torch.zeros(60)
            
           counter = 0 
                
           # Every 100 repetitions print accuracy
           if repetitions_train%100 == 0:
                print("Training accuracy:", accuracy_train/repetitions_train)
# Out:
# Batch interaction:  1
# Batch interaction:  2
# Batch interaction:  3
# Batch interaction:  4
# Batch interaction:  5
# Batch interaction:  6
# Batch interaction:  7
# Batch interaction:  8
# Batch interaction:  9
# Batch interaction:  10
# Batch interaction:  11
# Batch interaction:  12
# Batch interaction:  13
# Batch interaction:  14
# Batch interaction:  15
# Batch interaction:  16
# Batch interaction:  17
# Batch interaction:  18
# Batch interaction:  19
# Batch interaction:  20
# Batch interaction:  21
# Batch interaction:  22
# Batch interaction:  23
# Batch interaction:  24
# Batch interaction:  25
# Batch interaction:  26
# Batch interaction:  27
# Batch interaction:  28
# Batch interaction:  29
# Batch interaction:  30
# Batch interaction:  31
# Batch interaction:  32
# Batch interaction:  33
# Batch interaction:  34
# Batch interaction:  35
# Batch interaction:  36
# Batch interaction:  37
# Batch interaction:  38
# Batch interaction:  39
# Batch interaction:  40
# Batch interaction:  41
# Batch interaction:  42
# Batch interaction:  43
# Batch interaction:  44
# Batch interaction:  45
# Batch interaction:  46
# Batch interaction:  47
# Batch interaction:  48
# Batch interaction:  49
# Batch interaction:  50
# Batch interaction:  51
# Batch interaction:  52
# Batch interaction:  53
# Batch interaction:  54
# Batch interaction:  55
# Batch interaction:  56
# Batch interaction:  57
# Batch interaction:  58
# Batch interaction:  59
# Batch interaction:  60
# Batch interaction:  61
# Batch interaction:  62
# Batch interaction:  63
# Batch interaction:  64
# Batch interaction:  65
# Batch interaction:  66
# Batch interaction:  67
# Batch interaction:  68
# Batch interaction:  69
# Batch interaction:  70
# Batch interaction:  71
# Batch interaction:  72
# Batch interaction:  73
# Batch interaction:  74
# Batch interaction:  75
# Batch interaction:  76
# Batch interaction:  77
# Batch interaction:  78
# Batch interaction:  79
# Batch interaction:  80
# Batch interaction:  81
# Batch interaction:  82
# Batch interaction:  83
# Batch interaction:  84
# Batch interaction:  85
# Batch interaction:  86
# Batch interaction:  87
# Batch interaction:  88
# Batch interaction:  89
# Batch interaction:  90
# Batch interaction:  91
# Batch interaction:  92
# Batch interaction:  93
# Batch interaction:  94
# Batch interaction:  95
# Batch interaction:  96
# Batch interaction:  97
# Batch interaction:  98
# Batch interaction:  99
# Batch interaction:  100
# Training accuracy: tensor(0.8650)
# Batch interaction:  101
# Batch interaction:  102
# Batch interaction:  103
# Batch interaction:  104
# Batch interaction:  105
# Batch interaction:  106
# Batch interaction:  107
# Batch interaction:  108
# Batch interaction:  109
# Batch interaction:  110
# Batch interaction:  111
# Batch interaction:  112
# Batch interaction:  113
# Batch interaction:  114
# Batch interaction:  115
# Batch interaction:  116
# Batch interaction:  117
# Batch interaction:  118
# Batch interaction:  119
# Batch interaction:  120
# Batch interaction:  121
# Batch interaction:  122
# Batch interaction:  123
# Batch interaction:  124
# Batch interaction:  125
# Batch interaction:  126
# Batch interaction:  127
# Batch interaction:  128
# Batch interaction:  129
# Batch interaction:  130
# Batch interaction:  131
# Batch interaction:  132
# Batch interaction:  133
# Batch interaction:  134
# Batch interaction:  135
# Batch interaction:  136
# Batch interaction:  137
# Batch interaction:  138
# Batch interaction:  139
# Batch interaction:  140
# Batch interaction:  141
# Batch interaction:  142
# Batch interaction:  143
# Batch interaction:  144
# Batch interaction:  145
# Batch interaction:  146
# Batch interaction:  147
# Batch interaction:  148
# Batch interaction:  149
# Batch interaction:  150
# Batch interaction:  151
# Batch interaction:  152
# Batch interaction:  153
# Batch interaction:  154
# Batch interaction:  155
# Batch interaction:  156
# Batch interaction:  157
# Batch interaction:  158
# Batch interaction:  159
# Batch interaction:  160
# Batch interaction:  161
# Batch interaction:  162
# Batch interaction:  163
# Batch interaction:  164
# Batch interaction:  165
# Batch interaction:  166
# Batch interaction:  167
# Batch interaction:  168
# Batch interaction:  169
# Batch interaction:  170
# Batch interaction:  171
# Batch interaction:  172
# Batch interaction:  173
# Batch interaction:  174
# Batch interaction:  175
# Batch interaction:  176
# Batch interaction:  177
# Batch interaction:  178
# Batch interaction:  179
# Batch interaction:  180
# Batch interaction:  181
# Batch interaction:  182
# Batch interaction:  183
# Batch interaction:  184
# Batch interaction:  185
# Batch interaction:  186
# Batch interaction:  187
# Batch interaction:  188
# Batch interaction:  189
# Batch interaction:  190
# Batch interaction:  191
# Batch interaction:  192
# Batch interaction:  193
# Batch interaction:  194
# Batch interaction:  195
# Batch interaction:  196
# Batch interaction:  197
# Batch interaction:  198
# Batch interaction:  199
# Batch interaction:  200
# Training accuracy: tensor(0.8647)
# Batch interaction:  201
# Batch interaction:  202
# Batch interaction:  203
# Batch interaction:  204
# Batch interaction:  205
# Batch interaction:  206
# Batch interaction:  207
# Batch interaction:  208
# Batch interaction:  209
# Batch interaction:  210
# Batch interaction:  211
# Batch interaction:  212
# Batch interaction:  213
# Batch interaction:  214
# Batch interaction:  215
# Batch interaction:  216
# Batch interaction:  217
# Batch interaction:  218
# Batch interaction:  219
# Batch interaction:  220
# Batch interaction:  221
# Batch interaction:  222
# Batch interaction:  223
# Batch interaction:  224
# Batch interaction:  225
# Batch interaction:  226
# Batch interaction:  227
# Batch interaction:  228
# Batch interaction:  229
# Batch interaction:  230
# Batch interaction:  231
# Batch interaction:  232
# Batch interaction:  233
# Batch interaction:  234
# Batch interaction:  235
# Batch interaction:  236
# Batch interaction:  237
# Batch interaction:  238
# Batch interaction:  239
# Batch interaction:  240
# Batch interaction:  241
# Batch interaction:  242
# Batch interaction:  243
# Batch interaction:  244
# Batch interaction:  245
# Batch interaction:  246
# Batch interaction:  247
# Batch interaction:  248
# Batch interaction:  249
# Batch interaction:  250
# Batch interaction:  251
# Batch interaction:  252
# Batch interaction:  253
# Batch interaction:  254
# Batch interaction:  255
# Batch interaction:  256
# Batch interaction:  257
# Batch interaction:  258
# Batch interaction:  259
# Batch interaction:  260
# Batch interaction:  261
# Batch interaction:  262
# Batch interaction:  263
# Batch interaction:  264
# Batch interaction:  265
# Batch interaction:  266
# Batch interaction:  267
# Batch interaction:  268
# Batch interaction:  269
# Batch interaction:  270
# Batch interaction:  271
# Batch interaction:  272
# Batch interaction:  273
# Batch interaction:  274
# Batch interaction:  275
# Batch interaction:  276
# Batch interaction:  277
# Batch interaction:  278
# Batch interaction:  279
# Batch interaction:  280
# Batch interaction:  281
# Batch interaction:  282
# Batch interaction:  283
# Batch interaction:  284
# Batch interaction:  285
# Batch interaction:  286
# Batch interaction:  287
# Batch interaction:  288
# Batch interaction:  289
# Batch interaction:  290
# Batch interaction:  291
# Batch interaction:  292
# Batch interaction:  293
# Batch interaction:  294
# Batch interaction:  295
# Batch interaction:  296
# Batch interaction:  297
# Batch interaction:  298
# Batch interaction:  299
# Batch interaction:  300
# Training accuracy: tensor(0.8668)
# Batch interaction:  301
# Batch interaction:  302
# Batch interaction:  303
# Batch interaction:  304
# Batch interaction:  305
# Batch interaction:  306
# Batch interaction:  307
# Batch interaction:  308
# Batch interaction:  309
# Batch interaction:  310
# Batch interaction:  311
# Batch interaction:  312
# Batch interaction:  313
# Batch interaction:  314
# Batch interaction:  315
# Batch interaction:  316
# Batch interaction:  317
# Batch interaction:  318
# Batch interaction:  319
# Batch interaction:  320
# Batch interaction:  321
# Batch interaction:  322
# Batch interaction:  323
# Batch interaction:  324
# Batch interaction:  325
# Batch interaction:  326
# Batch interaction:  327
# Batch interaction:  328
# Batch interaction:  329
# Batch interaction:  330
# Batch interaction:  331
# Batch interaction:  332
# Batch interaction:  333
# Batch interaction:  334
# Batch interaction:  335
# Batch interaction:  336
# Batch interaction:  337
# Batch interaction:  338
# Batch interaction:  339
# Batch interaction:  340
# Batch interaction:  341
# Batch interaction:  342
# Batch interaction:  343
# Batch interaction:  344
# Batch interaction:  345
# Batch interaction:  346
# Batch interaction:  347
# Batch interaction:  348
# Batch interaction:  349
# Batch interaction:  350
# Batch interaction:  351
# Batch interaction:  352
# Batch interaction:  353
# Batch interaction:  354
# Batch interaction:  355
# Batch interaction:  356
# Batch interaction:  357
# Batch interaction:  358
# Batch interaction:  359
# Batch interaction:  360
# Batch interaction:  361
# Batch interaction:  362
# Batch interaction:  363
# Batch interaction:  364
# Batch interaction:  365
# Batch interaction:  366
# Batch interaction:  367
# Batch interaction:  368
# Batch interaction:  369
# Batch interaction:  370
# Batch interaction:  371
# Batch interaction:  372
# Batch interaction:  373
# Batch interaction:  374
# Batch interaction:  375
# Batch interaction:  376
# Batch interaction:  377
# Batch interaction:  378
# Batch interaction:  379
# Batch interaction:  380
# Batch interaction:  381
# Batch interaction:  382
# Batch interaction:  383
# Batch interaction:  384
# Batch interaction:  385
# Batch interaction:  386
# Batch interaction:  387
# Batch interaction:  388
# Batch interaction:  389
# Batch interaction:  390
# Batch interaction:  391
# Batch interaction:  392
# Batch interaction:  393
# Batch interaction:  394
# Batch interaction:  395
# Batch interaction:  396
# Batch interaction:  397
# Batch interaction:  398
# Batch interaction:  399
# Batch interaction:  400
# Training accuracy: tensor(0.8653)
# Batch interaction:  401
# Batch interaction:  402
# Batch interaction:  403
# Batch interaction:  404
# Batch interaction:  405
# Batch interaction:  406
# Batch interaction:  407
# Batch interaction:  408
# Batch interaction:  409
# Batch interaction:  410
# Batch interaction:  411
# Batch interaction:  412
# Batch interaction:  413
# Batch interaction:  414
# Batch interaction:  415
# Batch interaction:  416
# Batch interaction:  417
# Batch interaction:  418
# Batch interaction:  419
# Batch interaction:  420
# Batch interaction:  421
# Batch interaction:  422
# Batch interaction:  423
# Batch interaction:  424
# Batch interaction:  425
# Batch interaction:  426
# Batch interaction:  427
# Batch interaction:  428
# Batch interaction:  429
# Batch interaction:  430
# Batch interaction:  431
# Batch interaction:  432
# Batch interaction:  433
# Batch interaction:  434
# Batch interaction:  435
# Batch interaction:  436
# Batch interaction:  437
# Batch interaction:  438
# Batch interaction:  439
# Batch interaction:  440
# Batch interaction:  441
# Batch interaction:  442
# Batch interaction:  443
# Batch interaction:  444
# Batch interaction:  445
# Batch interaction:  446
# Batch interaction:  447
# Batch interaction:  448
# Batch interaction:  449
# Batch interaction:  450
# Batch interaction:  451
# Batch interaction:  452
# Batch interaction:  453
# Batch interaction:  454
# Batch interaction:  455
# Batch interaction:  456
# Batch interaction:  457
# Batch interaction:  458
# Batch interaction:  459
# Batch interaction:  460
# Batch interaction:  461
# Batch interaction:  462
# Batch interaction:  463
# Batch interaction:  464
# Batch interaction:  465
# Batch interaction:  466
# Batch interaction:  467
# Batch interaction:  468
# Batch interaction:  469
# Batch interaction:  470
# Batch interaction:  471
# Batch interaction:  472
# Batch interaction:  473
# Batch interaction:  474
# Batch interaction:  475
# Batch interaction:  476
# Batch interaction:  477
# Batch interaction:  478
# Batch interaction:  479
# Batch interaction:  480
# Batch interaction:  481
# Batch interaction:  482
# Batch interaction:  483
# Batch interaction:  484
# Batch interaction:  485
# Batch interaction:  486
# Batch interaction:  487
# Batch interaction:  488
# Batch interaction:  489
# Batch interaction:  490
# Batch interaction:  491
# Batch interaction:  492
# Batch interaction:  493
# Batch interaction:  494
# Batch interaction:  495
# Batch interaction:  496
# Batch interaction:  497
# Batch interaction:  498
# Batch interaction:  499
# Batch interaction:  500
# Training accuracy: tensor(0.8639)
# Batch interaction:  501
# Batch interaction:  502
# Batch interaction:  503
# Batch interaction:  504
# Batch interaction:  505
# Batch interaction:  506
# Batch interaction:  507
# Batch interaction:  508
# Batch interaction:  509
# Batch interaction:  510
# Batch interaction:  511
# Batch interaction:  512
# Batch interaction:  513
# Batch interaction:  514
# Batch interaction:  515
# Batch interaction:  516
# Batch interaction:  517
# Batch interaction:  518
# Batch interaction:  519
# Batch interaction:  520
# Batch interaction:  521
# Batch interaction:  522
# Batch interaction:  523
# Batch interaction:  524
# Batch interaction:  525
# Batch interaction:  526
# Batch interaction:  527
# Batch interaction:  528
# Batch interaction:  529
# Batch interaction:  530
# Batch interaction:  531
# Batch interaction:  532
# Batch interaction:  533
# Batch interaction:  534
# Batch interaction:  535
# Batch interaction:  536
# Batch interaction:  537
# Batch interaction:  538
# Batch interaction:  539
# Batch interaction:  540
# Batch interaction:  541
# Batch interaction:  542
# Batch interaction:  543
# Batch interaction:  544
# Batch interaction:  545
# Batch interaction:  546
# Batch interaction:  547
# Batch interaction:  548
# Batch interaction:  549
# Batch interaction:  550
# Batch interaction:  551
# Batch interaction:  552
# Batch interaction:  553
# Batch interaction:  554
# Batch interaction:  555
# Batch interaction:  556
# Batch interaction:  557
# Batch interaction:  558
# Batch interaction:  559
# Batch interaction:  560
# Batch interaction:  561
# Batch interaction:  562
# Batch interaction:  563
# Batch interaction:  564
# Batch interaction:  565
# Batch interaction:  566
# Batch interaction:  567
# Batch interaction:  568
# Batch interaction:  569
# Batch interaction:  570
# Batch interaction:  571
# Batch interaction:  572
# Batch interaction:  573
# Batch interaction:  574
# Batch interaction:  575
# Batch interaction:  576
# Batch interaction:  577
# Batch interaction:  578
# Batch interaction:  579
# Batch interaction:  580
# Batch interaction:  581
# Batch interaction:  582
# Batch interaction:  583
# Batch interaction:  584
# Batch interaction:  585
# Batch interaction:  586
# Batch interaction:  587
# Batch interaction:  588
# Batch interaction:  589
# Batch interaction:  590
# Batch interaction:  591
# Batch interaction:  592
# Batch interaction:  593
# Batch interaction:  594
# Batch interaction:  595
# Batch interaction:  596
# Batch interaction:  597
# Batch interaction:  598
# Batch interaction:  599
# Batch interaction:  600
# Training accuracy: tensor(0.8641)
# Batch interaction:  601
# Batch interaction:  602
# Batch interaction:  603
# Batch interaction:  604
# Batch interaction:  605
# Batch interaction:  606
# Batch interaction:  607
# Batch interaction:  608
# Batch interaction:  609
# Batch interaction:  610
# Batch interaction:  611
# Batch interaction:  612
# Batch interaction:  613
# Batch interaction:  614
# Batch interaction:  615
# Batch interaction:  616
# Batch interaction:  617
# Batch interaction:  618
# Batch interaction:  619
# Batch interaction:  620
# Batch interaction:  621
# Batch interaction:  622
# Batch interaction:  623
# Batch interaction:  624
# Batch interaction:  625
# Batch interaction:  626
# Batch interaction:  627
# Batch interaction:  628
# Batch interaction:  629
# Batch interaction:  630
# Batch interaction:  631
# Batch interaction:  632
# Batch interaction:  633
# Batch interaction:  634
# Batch interaction:  635
# Batch interaction:  636
# Batch interaction:  637
# Batch interaction:  638
# Batch interaction:  639
# Batch interaction:  640
# Batch interaction:  641
# Batch interaction:  642
# Batch interaction:  643
# Batch interaction:  644
# Batch interaction:  645
# Batch interaction:  646
# Batch interaction:  647
# Batch interaction:  648
# Batch interaction:  649
# Batch interaction:  650
# Batch interaction:  651
# Batch interaction:  652
# Batch interaction:  653
# Batch interaction:  654
# Batch interaction:  655
# Batch interaction:  656
# Batch interaction:  657
# Batch interaction:  658
# Batch interaction:  659
# Batch interaction:  660
# Batch interaction:  661
# Batch interaction:  662
# Batch interaction:  663
# Batch interaction:  664
# Batch interaction:  665
# Batch interaction:  666
# Batch interaction:  667
# Batch interaction:  668
# Batch interaction:  669
# Batch interaction:  670
# Batch interaction:  671
# Batch interaction:  672
# Batch interaction:  673
# Batch interaction:  674
# Batch interaction:  675
# Batch interaction:  676
# Batch interaction:  677
# Batch interaction:  678
# Batch interaction:  679
# Batch interaction:  680
# Batch interaction:  681
# Batch interaction:  682
# Batch interaction:  683
# Batch interaction:  684
# Batch interaction:  685
# Batch interaction:  686
# Batch interaction:  687
# Batch interaction:  688
# Batch interaction:  689
# Batch interaction:  690
# Batch interaction:  691
# Batch interaction:  692
# Batch interaction:  693
# Batch interaction:  694
# Batch interaction:  695
# Batch interaction:  696
# Batch interaction:  697
# Batch interaction:  698
# Batch interaction:  699
# Batch interaction:  700
# Training accuracy: tensor(0.8651)
# Batch interaction:  701
# Batch interaction:  702
# Batch interaction:  703
# Batch interaction:  704
# Batch interaction:  705
# Batch interaction:  706
# Batch interaction:  707
# Batch interaction:  708
# Batch interaction:  709
# Batch interaction:  710
# Batch interaction:  711
# Batch interaction:  712
# Batch interaction:  713
# Batch interaction:  714
# Batch interaction:  715
# Batch interaction:  716
# Batch interaction:  717
# Batch interaction:  718
# Batch interaction:  719
# Batch interaction:  720
# Batch interaction:  721
# Batch interaction:  722
# Batch interaction:  723
# Batch interaction:  724
# Batch interaction:  725
# Batch interaction:  726
# Batch interaction:  727
# Batch interaction:  728
# Batch interaction:  729
# Batch interaction:  730
# Batch interaction:  731
# Batch interaction:  732
# Batch interaction:  733
# Batch interaction:  734
# Batch interaction:  735
# Batch interaction:  736
# Batch interaction:  737
# Batch interaction:  738
# Batch interaction:  739
# Batch interaction:  740
# Batch interaction:  741
# Batch interaction:  742
# Batch interaction:  743
# Batch interaction:  744
# Batch interaction:  745
# Batch interaction:  746
# Batch interaction:  747
# Batch interaction:  748
# Batch interaction:  749
# Batch interaction:  750
# Batch interaction:  751
# Batch interaction:  752
# Batch interaction:  753
# Batch interaction:  754
# Batch interaction:  755
# Batch interaction:  756
# Batch interaction:  757
# Batch interaction:  758
# Batch interaction:  759
# Batch interaction:  760
# Batch interaction:  761
# Batch interaction:  762
# Batch interaction:  763
# Batch interaction:  764
# Batch interaction:  765
# Batch interaction:  766
# Batch interaction:  767
# Batch interaction:  768
# Batch interaction:  769
# Batch interaction:  770
# Batch interaction:  771
# Batch interaction:  772
# Batch interaction:  773
# Batch interaction:  774
# Batch interaction:  775
# Batch interaction:  776
# Batch interaction:  777
# Batch interaction:  778
# Batch interaction:  779
# Batch interaction:  780
# Batch interaction:  781
# Batch interaction:  782
# Batch interaction:  783
# Batch interaction:  784
# Batch interaction:  785
# Batch interaction:  786
# Batch interaction:  787
# Batch interaction:  788
# Batch interaction:  789
# Batch interaction:  790
# Batch interaction:  791
# Batch interaction:  792
# Batch interaction:  793
# Batch interaction:  794
# Batch interaction:  795
# Batch interaction:  796
# Batch interaction:  797
# Batch interaction:  798
# Batch interaction:  799
# Batch interaction:  800
# Training accuracy: tensor(0.8652)
# Batch interaction:  801
# Batch interaction:  802
# Batch interaction:  803
# Batch interaction:  804
# Batch interaction:  805
# Batch interaction:  806
# Batch interaction:  807
# Batch interaction:  808
# Batch interaction:  809
# Batch interaction:  810
# Batch interaction:  811
# Batch interaction:  812
# Batch interaction:  813
# Batch interaction:  814
# Batch interaction:  815
# Batch interaction:  816
# Batch interaction:  817
# Batch interaction:  818
# Batch interaction:  819
# Batch interaction:  820
# Batch interaction:  821
# Batch interaction:  822
# Batch interaction:  823
# Batch interaction:  824
# Batch interaction:  825
# Batch interaction:  826
# Batch interaction:  827
# Batch interaction:  828
# Batch interaction:  829
# Batch interaction:  830
# Batch interaction:  831
# Batch interaction:  832
# Batch interaction:  833
# Batch interaction:  834
# Batch interaction:  835
# Batch interaction:  836
# Batch interaction:  837
# Batch interaction:  838
# Batch interaction:  839
# Batch interaction:  840
# Batch interaction:  841
# Batch interaction:  842
# Batch interaction:  843
# Batch interaction:  844
# Batch interaction:  845
# Batch interaction:  846
# Batch interaction:  847
# Batch interaction:  848
# Batch interaction:  849
# Batch interaction:  850
# Batch interaction:  851
# Batch interaction:  852
# Batch interaction:  853
# Batch interaction:  854
# Batch interaction:  855
# Batch interaction:  856
# Batch interaction:  857
# Batch interaction:  858
# Batch interaction:  859
# Batch interaction:  860
# Batch interaction:  861
# Batch interaction:  862
# Batch interaction:  863
# Batch interaction:  864
# Batch interaction:  865
# Batch interaction:  866
# Batch interaction:  867
# Batch interaction:  868
# Batch interaction:  869
# Batch interaction:  870
# Batch interaction:  871
# Batch interaction:  872
# Batch interaction:  873
# Batch interaction:  874
# Batch interaction:  875
# Batch interaction:  876
# Batch interaction:  877
# Batch interaction:  878
# Batch interaction:  879
# Batch interaction:  880
# Batch interaction:  881
# Batch interaction:  882
# Batch interaction:  883
# Batch interaction:  884
# Batch interaction:  885
# Batch interaction:  886
# Batch interaction:  887
# Batch interaction:  888
# Batch interaction:  889
# Batch interaction:  890
# Batch interaction:  891
# Batch interaction:  892
# Batch interaction:  893
# Batch interaction:  894
# Batch interaction:  895
# Batch interaction:  896
# Batch interaction:  897
# Batch interaction:  898
# Batch interaction:  899
# Batch interaction:  900
# Training accuracy: tensor(0.8645)
# Batch interaction:  901
# Batch interaction:  902
# Batch interaction:  903
# Batch interaction:  904
# Batch interaction:  905
# Batch interaction:  906
# Batch interaction:  907
# Batch interaction:  908
# Batch interaction:  909
# Batch interaction:  910
# Batch interaction:  911
# Batch interaction:  912
# Batch interaction:  913
# Batch interaction:  914
# Batch interaction:  915
# Batch interaction:  916
# Batch interaction:  917
# Batch interaction:  918
# Batch interaction:  919
# Batch interaction:  920
# Batch interaction:  921
# Batch interaction:  922
# Batch interaction:  923
# Batch interaction:  924
# Batch interaction:  925
# Batch interaction:  926
# Batch interaction:  927
# Batch interaction:  928
# Batch interaction:  929
# Batch interaction:  930
# Batch interaction:  931
# Batch interaction:  932
# Batch interaction:  933
# Batch interaction:  934
# Batch interaction:  935
# Batch interaction:  936
# Batch interaction:  937
# Batch interaction:  938
# Batch interaction:  939
# Batch interaction:  940
# Batch interaction:  941
# Batch interaction:  942
# Batch interaction:  943
# Batch interaction:  944
# Batch interaction:  945
# Batch interaction:  946
# Batch interaction:  947
# Batch interaction:  948
# Batch interaction:  949
# Batch interaction:  950
# Batch interaction:  951
# Batch interaction:  952
# Batch interaction:  953
# Batch interaction:  954
# Batch interaction:  955
# Batch interaction:  956
# Batch interaction:  957
# Batch interaction:  958
# Batch interaction:  959
# Batch interaction:  960
# Batch interaction:  961
# Batch interaction:  962
# Batch interaction:  963
# Batch interaction:  964
# Batch interaction:  965
# Batch interaction:  966
# Batch interaction:  967
# Batch interaction:  968
# Batch interaction:  969
# Batch interaction:  970
# Batch interaction:  971
# Batch interaction:  972
# Batch interaction:  973
# Batch interaction:  974
# Batch interaction:  975
# Batch interaction:  976
# Batch interaction:  977
# Batch interaction:  978
# Batch interaction:  979
# Batch interaction:  980
# Batch interaction:  981
# Batch interaction:  982
# Batch interaction:  983
# Batch interaction:  984
# Batch interaction:  985
# Batch interaction:  986
# Batch interaction:  987
# Batch interaction:  988
# Batch interaction:  989
# Batch interaction:  990
# Batch interaction:  991
# Batch interaction:  992
# Batch interaction:  993
# Batch interaction:  994
# Batch interaction:  995
# Batch interaction:  996
# Batch interaction:  997
# Batch interaction:  998
# Batch interaction:  999
# Batch interaction:  1000
# Training accuracy: tensor(0.8651)
# Batch interaction:  1001
# Batch interaction:  1002
# Batch interaction:  1003
# Batch interaction:  1004
# Batch interaction:  1005
# Batch interaction:  1006
# Batch interaction:  1007
# Batch interaction:  1008
# Batch interaction:  1009
# Batch interaction:  1010
# Batch interaction:  1011
# Batch interaction:  1012
# Batch interaction:  1013
# Batch interaction:  1014
# Batch interaction:  1015
# Batch interaction:  1016
# Batch interaction:  1017
# Batch interaction:  1018
# Batch interaction:  1019
# Batch interaction:  1020
# Batch interaction:  1021
# Batch interaction:  1022
# Batch interaction:  1023
# Batch interaction:  1024
# Batch interaction:  1025
# Batch interaction:  1026
# Batch interaction:  1027
# Batch interaction:  1028
# Batch interaction:  1029
# Batch interaction:  1030
# Batch interaction:  1031
# Batch interaction:  1032
# Batch interaction:  1033
# Batch interaction:  1034
# Batch interaction:  1035
# Batch interaction:  1036
# Batch interaction:  1037
# Batch interaction:  1038
# Batch interaction:  1039
# Batch interaction:  1040
# Batch interaction:  1041
# Batch interaction:  1042
# Batch interaction:  1043
# Batch interaction:  1044
# Batch interaction:  1045
# Batch interaction:  1046
# Batch interaction:  1047
# Batch interaction:  1048
# Batch interaction:  1049
# Batch interaction:  1050
# Batch interaction:  1051
# Batch interaction:  1052
# Batch interaction:  1053
# Batch interaction:  1054
# Batch interaction:  1055
# Batch interaction:  1056
# Batch interaction:  1057
# Batch interaction:  1058
# Batch interaction:  1059
# Batch interaction:  1060
# Batch interaction:  1061
# Batch interaction:  1062
# Batch interaction:  1063
# Batch interaction:  1064
# Batch interaction:  1065
# Batch interaction:  1066
# Batch interaction:  1067
# Batch interaction:  1068
# Batch interaction:  1069
# Batch interaction:  1070
# Batch interaction:  1071
# Batch interaction:  1072
# Batch interaction:  1073
# Batch interaction:  1074
# Batch interaction:  1075
# Batch interaction:  1076
# Batch interaction:  1077
# Batch interaction:  1078
# Batch interaction:  1079
# Batch interaction:  1080
# Batch interaction:  1081
# Batch interaction:  1082
# Batch interaction:  1083
# Batch interaction:  1084
# Batch interaction:  1085
# Batch interaction:  1086
# Batch interaction:  1087
# Batch interaction:  1088
# Batch interaction:  1089
# Batch interaction:  1090
# Batch interaction:  1091
# Batch interaction:  1092
# Batch interaction:  1093
# Batch interaction:  1094
# Batch interaction:  1095
# Batch interaction:  1096
# Batch interaction:  1097
# Batch interaction:  1098
# Batch interaction:  1099
# Batch interaction:  1100
# Training accuracy: tensor(0.8656)
# Batch interaction:  1101
# Batch interaction:  1102
# Batch interaction:  1103
# Batch interaction:  1104
# Batch interaction:  1105
# Batch interaction:  1106
# Batch interaction:  1107
# Batch interaction:  1108
# Batch interaction:  1109
# Batch interaction:  1110
# Batch interaction:  1111
# Batch interaction:  1112
# Batch interaction:  1113
# Batch interaction:  1114
# Batch interaction:  1115
# Batch interaction:  1116
# Batch interaction:  1117
# Batch interaction:  1118
# Batch interaction:  1119
# Batch interaction:  1120
# Batch interaction:  1121
# Batch interaction:  1122
# Batch interaction:  1123
# Batch interaction:  1124
# Batch interaction:  1125
# Batch interaction:  1126
# Batch interaction:  1127
# Batch interaction:  1128
# Batch interaction:  1129
# Batch interaction:  1130
# Batch interaction:  1131
# Batch interaction:  1132
# Batch interaction:  1133
# Batch interaction:  1134
# Batch interaction:  1135
# Batch interaction:  1136
# Batch interaction:  1137
# Batch interaction:  1138
# Batch interaction:  1139
# Batch interaction:  1140
# Batch interaction:  1141
# Batch interaction:  1142
# Batch interaction:  1143
# Batch interaction:  1144
# Batch interaction:  1145
# Batch interaction:  1146
# Batch interaction:  1147
# Batch interaction:  1148
# Batch interaction:  1149
# Batch interaction:  1150
# Batch interaction:  1151
# Batch interaction:  1152
# Batch interaction:  1153
# Batch interaction:  1154
# Batch interaction:  1155
# Batch interaction:  1156
# Batch interaction:  1157
# Batch interaction:  1158
# Batch interaction:  1159
# Batch interaction:  1160
# Batch interaction:  1161
# Batch interaction:  1162
# Batch interaction:  1163
# Batch interaction:  1164
# Batch interaction:  1165
# Batch interaction:  1166
# Batch interaction:  1167
# Batch interaction:  1168
# Batch interaction:  1169
# Batch interaction:  1170
# Batch interaction:  1171
# Batch interaction:  1172
# Batch interaction:  1173
# Batch interaction:  1174
# Batch interaction:  1175
# Batch interaction:  1176
# Batch interaction:  1177
# Batch interaction:  1178
# Batch interaction:  1179
# Batch interaction:  1180
# Batch interaction:  1181
# Batch interaction:  1182
# Batch interaction:  1183
# Batch interaction:  1184
# Batch interaction:  1185
# Batch interaction:  1186
# Batch interaction:  1187
# Batch interaction:  1188
# Batch interaction:  1189
# Batch interaction:  1190
# Batch interaction:  1191
# Batch interaction:  1192
# Batch interaction:  1193
# Batch interaction:  1194
# Batch interaction:  1195
# Batch interaction:  1196
# Batch interaction:  1197
# Batch interaction:  1198
# Batch interaction:  1199
# Batch interaction:  1200
# Training accuracy: tensor(0.8659)
# Batch interaction:  1201
# Batch interaction:  1202
# Batch interaction:  1203
# Batch interaction:  1204
# Batch interaction:  1205
# Batch interaction:  1206
# Batch interaction:  1207
# Batch interaction:  1208
# Batch interaction:  1209
# Batch interaction:  1210
# Batch interaction:  1211
# Batch interaction:  1212
# Batch interaction:  1213
# Batch interaction:  1214
# Batch interaction:  1215
# Batch interaction:  1216
# Batch interaction:  1217
# Batch interaction:  1218
# Batch interaction:  1219
# Batch interaction:  1220
# Batch interaction:  1221
# Batch interaction:  1222
# Batch interaction:  1223
# Batch interaction:  1224
# Batch interaction:  1225
# Batch interaction:  1226
# Batch interaction:  1227
# Batch interaction:  1228
# Batch interaction:  1229
# Batch interaction:  1230
# Batch interaction:  1231
# Batch interaction:  1232
# Batch interaction:  1233
# Batch interaction:  1234
# Batch interaction:  1235
# Batch interaction:  1236
# Batch interaction:  1237
# Batch interaction:  1238
# Batch interaction:  1239
# Batch interaction:  1240
# Batch interaction:  1241
# Batch interaction:  1242
# Batch interaction:  1243
# Batch interaction:  1244
# Batch interaction:  1245
# Batch interaction:  1246
# Batch interaction:  1247
# Batch interaction:  1248
# Batch interaction:  1249
# Batch interaction:  1250
# Batch interaction:  1251
# Batch interaction:  1252
# Batch interaction:  1253
# Batch interaction:  1254
# Batch interaction:  1255
# Batch interaction:  1256
# Batch interaction:  1257
# Batch interaction:  1258
# Batch interaction:  1259
# Batch interaction:  1260
# Batch interaction:  1261
# Batch interaction:  1262
# Batch interaction:  1263
# Batch interaction:  1264
# Batch interaction:  1265
# Batch interaction:  1266
# Batch interaction:  1267
# Batch interaction:  1268
# Batch interaction:  1269
# Batch interaction:  1270
# Batch interaction:  1271
# Batch interaction:  1272
# Batch interaction:  1273
# Batch interaction:  1274
# Batch interaction:  1275
# Batch interaction:  1276
# Batch interaction:  1277
# Batch interaction:  1278
# Batch interaction:  1279
# Batch interaction:  1280
# Batch interaction:  1281
# Batch interaction:  1282
# Batch interaction:  1283
# Batch interaction:  1284
# Batch interaction:  1285
# Batch interaction:  1286
# Batch interaction:  1287
# Batch interaction:  1288
# Batch interaction:  1289
# Batch interaction:  1290
# Batch interaction:  1291
# Batch interaction:  1292
# Batch interaction:  1293
# Batch interaction:  1294
# Batch interaction:  1295
# Batch interaction:  1296
# Batch interaction:  1297
# Batch interaction:  1298
# Batch interaction:  1299
# Batch interaction:  1300
# Training accuracy: tensor(0.8661)
# Batch interaction:  1301
# Batch interaction:  1302
# Batch interaction:  1303
# Batch interaction:  1304
# Batch interaction:  1305
# Batch interaction:  1306
# Batch interaction:  1307
# Batch interaction:  1308
# Batch interaction:  1309
# Batch interaction:  1310
# Batch interaction:  1311
# Batch interaction:  1312
# Batch interaction:  1313
# Batch interaction:  1314
# Batch interaction:  1315
# Batch interaction:  1316
# Batch interaction:  1317
# Batch interaction:  1318
# Batch interaction:  1319
# Batch interaction:  1320
# Batch interaction:  1321
# Batch interaction:  1322
# Batch interaction:  1323
# Batch interaction:  1324
# Batch interaction:  1325
# Batch interaction:  1326
# Batch interaction:  1327
# Batch interaction:  1328
# Batch interaction:  1329
# Batch interaction:  1330
# Batch interaction:  1331
# Batch interaction:  1332
# Batch interaction:  1333
# Batch interaction:  1334
# Batch interaction:  1335
# Batch interaction:  1336
# Batch interaction:  1337
# Batch interaction:  1338
# Batch interaction:  1339
# Batch interaction:  1340
# Batch interaction:  1341
# Batch interaction:  1342
# Batch interaction:  1343
# Batch interaction:  1344
# Batch interaction:  1345
# Batch interaction:  1346
# Batch interaction:  1347
# Batch interaction:  1348
# Batch interaction:  1349
# Batch interaction:  1350
# Batch interaction:  1351
# Batch interaction:  1352
# Batch interaction:  1353
# Batch interaction:  1354
# Batch interaction:  1355
# Batch interaction:  1356
# Batch interaction:  1357
# Batch interaction:  1358
# Batch interaction:  1359
# Batch interaction:  1360
# Batch interaction:  1361
# Batch interaction:  1362
# Batch interaction:  1363
# Batch interaction:  1364
# Batch interaction:  1365
# Batch interaction:  1366
# Batch interaction:  1367
# Batch interaction:  1368
# Batch interaction:  1369
# Batch interaction:  1370
# Batch interaction:  1371
# Batch interaction:  1372
# Batch interaction:  1373
# Batch interaction:  1374
# Batch interaction:  1375
# Batch interaction:  1376
# Batch interaction:  1377
# Batch interaction:  1378
# Batch interaction:  1379
# Batch interaction:  1380
# Batch interaction:  1381
# Batch interaction:  1382
# Batch interaction:  1383
# Batch interaction:  1384
# Batch interaction:  1385
# Batch interaction:  1386
# Batch interaction:  1387
# Batch interaction:  1388
# Batch interaction:  1389
# Batch interaction:  1390
# Batch interaction:  1391
# Batch interaction:  1392
# Batch interaction:  1393
# Batch interaction:  1394
# Batch interaction:  1395
# Batch interaction:  1396
# Batch interaction:  1397
# Batch interaction:  1398
# Batch interaction:  1399
# Batch interaction:  1400
# Training accuracy: tensor(0.8658)
# Batch interaction:  1401
# Batch interaction:  1402
# Batch interaction:  1403
# Batch interaction:  1404
# Batch interaction:  1405
# Batch interaction:  1406
# Batch interaction:  1407
# Batch interaction:  1408
# Batch interaction:  1409
# Batch interaction:  1410
# Batch interaction:  1411
# Batch interaction:  1412
# Batch interaction:  1413
# Batch interaction:  1414
# Batch interaction:  1415
# Batch interaction:  1416
# Batch interaction:  1417
# Batch interaction:  1418
# Batch interaction:  1419
# Batch interaction:  1420
# Batch interaction:  1421
# Batch interaction:  1422
# Batch interaction:  1423
# Batch interaction:  1424
# Batch interaction:  1425
# Batch interaction:  1426
# Batch interaction:  1427
# Batch interaction:  1428
# Batch interaction:  1429
# Batch interaction:  1430
# Batch interaction:  1431
# Batch interaction:  1432
# Batch interaction:  1433
# Batch interaction:  1434
# Batch interaction:  1435
# Batch interaction:  1436
# Batch interaction:  1437
# Batch interaction:  1438
# Batch interaction:  1439
# Batch interaction:  1440
# Batch interaction:  1441
# Batch interaction:  1442
# Batch interaction:  1443
# Batch interaction:  1444
# Batch interaction:  1445
# Batch interaction:  1446
# Batch interaction:  1447
# Batch interaction:  1448
# Batch interaction:  1449
# Batch interaction:  1450
# Batch interaction:  1451
# Batch interaction:  1452
# Batch interaction:  1453
# Batch interaction:  1454
# Batch interaction:  1455
# Batch interaction:  1456
# Batch interaction:  1457
# Batch interaction:  1458
# Batch interaction:  1459
# Batch interaction:  1460
# Batch interaction:  1461
# Batch interaction:  1462
# Batch interaction:  1463
# Batch interaction:  1464
# Batch interaction:  1465
# Batch interaction:  1466
# Batch interaction:  1467
# Batch interaction:  1468
# Batch interaction:  1469
# Batch interaction:  1470
# Batch interaction:  1471
# Batch interaction:  1472
# Batch interaction:  1473
# Batch interaction:  1474
# Batch interaction:  1475
# Batch interaction:  1476
# Batch interaction:  1477
# Batch interaction:  1478
# Batch interaction:  1479
# Batch interaction:  1480
# Batch interaction:  1481
# Batch interaction:  1482
# Batch interaction:  1483
# Batch interaction:  1484
# Batch interaction:  1485
# Batch interaction:  1486
# Batch interaction:  1487
# Batch interaction:  1488
# Batch interaction:  1489
# Batch interaction:  1490
# Batch interaction:  1491
# Batch interaction:  1492
# Batch interaction:  1493
# Batch interaction:  1494
# Batch interaction:  1495
# Batch interaction:  1496
# Batch interaction:  1497
# Batch interaction:  1498
# Batch interaction:  1499
# Batch interaction:  1500
# Training accuracy: tensor(0.8659)
# Batch interaction:  1501
# Batch interaction:  1502
# Batch interaction:  1503
# Batch interaction:  1504
# Batch interaction:  1505
# Batch interaction:  1506
# Batch interaction:  1507
# Batch interaction:  1508
# Batch interaction:  1509
# Batch interaction:  1510
# Batch interaction:  1511
# Batch interaction:  1512
# Batch interaction:  1513
# Batch interaction:  1514
# Batch interaction:  1515
# Batch interaction:  1516
# Batch interaction:  1517
# Batch interaction:  1518
# Batch interaction:  1519
# Batch interaction:  1520
# Batch interaction:  1521
# Batch interaction:  1522
# Batch interaction:  1523
# Batch interaction:  1524
# Batch interaction:  1525
# Batch interaction:  1526
# Batch interaction:  1527
# Batch interaction:  1528
# Batch interaction:  1529
# Batch interaction:  1530
# Batch interaction:  1531
# Batch interaction:  1532
# Batch interaction:  1533
# Batch interaction:  1534
# Batch interaction:  1535
# Batch interaction:  1536
# Batch interaction:  1537
# Batch interaction:  1538
# Batch interaction:  1539
# Batch interaction:  1540
# Batch interaction:  1541
# Batch interaction:  1542
# Batch interaction:  1543
# Batch interaction:  1544
# Batch interaction:  1545
# Batch interaction:  1546
# Batch interaction:  1547
# Batch interaction:  1548
# Batch interaction:  1549
# Batch interaction:  1550
# Batch interaction:  1551
# Batch interaction:  1552
# Batch interaction:  1553
# Batch interaction:  1554
# Batch interaction:  1555
# Batch interaction:  1556
# Batch interaction:  1557
# Batch interaction:  1558
# Batch interaction:  1559
# Batch interaction:  1560
# Batch interaction:  1561
# Batch interaction:  1562
# Batch interaction:  1563
# Batch interaction:  1564
# Batch interaction:  1565
# Batch interaction:  1566
# Batch interaction:  1567
# Batch interaction:  1568
# Batch interaction:  1569
# Batch interaction:  1570
# Batch interaction:  1571
# Batch interaction:  1572
# Batch interaction:  1573
# Batch interaction:  1574
# Batch interaction:  1575
# Batch interaction:  1576
# Batch interaction:  1577
# Batch interaction:  1578
# Batch interaction:  1579
# Batch interaction:  1580
# Batch interaction:  1581
# Batch interaction:  1582
# Batch interaction:  1583
# Batch interaction:  1584
# Batch interaction:  1585
# Batch interaction:  1586
# Batch interaction:  1587
# Batch interaction:  1588
# Batch interaction:  1589
# Batch interaction:  1590
# Batch interaction:  1591
# Batch interaction:  1592
# Batch interaction:  1593
# Batch interaction:  1594
# Batch interaction:  1595
# Batch interaction:  1596
# Batch interaction:  1597
# Batch interaction:  1598
# Batch interaction:  1599
# Batch interaction:  1600
# Training accuracy: tensor(0.8662)
# Batch interaction:  1601
# Batch interaction:  1602
# Batch interaction:  1603
# Batch interaction:  1604
# Batch interaction:  1605
# Batch interaction:  1606
# Batch interaction:  1607
# Batch interaction:  1608
# Batch interaction:  1609
# Batch interaction:  1610
# Batch interaction:  1611
# Batch interaction:  1612
# Batch interaction:  1613
# Batch interaction:  1614
# Batch interaction:  1615
# Batch interaction:  1616
# Batch interaction:  1617
# Batch interaction:  1618
# Batch interaction:  1619
# Batch interaction:  1620
# Batch interaction:  1621
# Batch interaction:  1622
# Batch interaction:  1623
# Batch interaction:  1624
# Batch interaction:  1625
# Batch interaction:  1626
# Batch interaction:  1627
# Batch interaction:  1628
# Batch interaction:  1629
# Batch interaction:  1630
# Batch interaction:  1631
# Batch interaction:  1632
# Batch interaction:  1633
# Batch interaction:  1634
# Batch interaction:  1635
# Batch interaction:  1636
# Batch interaction:  1637
# Batch interaction:  1638
# Batch interaction:  1639
# Batch interaction:  1640
# Batch interaction:  1641
# Batch interaction:  1642
# Batch interaction:  1643
# Batch interaction:  1644
# Batch interaction:  1645
# Batch interaction:  1646
# Batch interaction:  1647
# Batch interaction:  1648
# Batch interaction:  1649
# Batch interaction:  1650
# Batch interaction:  1651
# Batch interaction:  1652
# Batch interaction:  1653
# Batch interaction:  1654
# Batch interaction:  1655
# Batch interaction:  1656
# Batch interaction:  1657
# Batch interaction:  1658
# Batch interaction:  1659
# Batch interaction:  1660
# Batch interaction:  1661
# Batch interaction:  1662
# Batch interaction:  1663
# Batch interaction:  1664
# Batch interaction:  1665
# Batch interaction:  1666
# Batch interaction:  1667
# Batch interaction:  1668
# Batch interaction:  1669
# Batch interaction:  1670
# Batch interaction:  1671
# Batch interaction:  1672
# Batch interaction:  1673
# Batch interaction:  1674
# Batch interaction:  1675
# Batch interaction:  1676
# Batch interaction:  1677
# Batch interaction:  1678
# Batch interaction:  1679
# Batch interaction:  1680
# Batch interaction:  1681
# Batch interaction:  1682
# Batch interaction:  1683
# Batch interaction:  1684
# Batch interaction:  1685
# Batch interaction:  1686
# Batch interaction:  1687
# Batch interaction:  1688
# Batch interaction:  1689
# Batch interaction:  1690
# Batch interaction:  1691
# Batch interaction:  1692
# Batch interaction:  1693
# Batch interaction:  1694
# Batch interaction:  1695
# Batch interaction:  1696
# Batch interaction:  1697
# Batch interaction:  1698
# Batch interaction:  1699
# Batch interaction:  1700
# Training accuracy: tensor(0.8667)
# Batch interaction:  1701
# Batch interaction:  1702
# Batch interaction:  1703
# Batch interaction:  1704
# Batch interaction:  1705
# Batch interaction:  1706
# Batch interaction:  1707
# Batch interaction:  1708
# Batch interaction:  1709
# Batch interaction:  1710
# Batch interaction:  1711
# Batch interaction:  1712
# Batch interaction:  1713
# Batch interaction:  1714
# Batch interaction:  1715
# Batch interaction:  1716
# Batch interaction:  1717
# Batch interaction:  1718
# Batch interaction:  1719
# Batch interaction:  1720
# Batch interaction:  1721
# Batch interaction:  1722
# Batch interaction:  1723
# Batch interaction:  1724
# Batch interaction:  1725
# Batch interaction:  1726
# Batch interaction:  1727
# Batch interaction:  1728
# Batch interaction:  1729
# Batch interaction:  1730
# Batch interaction:  1731
# Batch interaction:  1732
# Batch interaction:  1733
# Batch interaction:  1734
# Batch interaction:  1735
# Batch interaction:  1736
# Batch interaction:  1737
# Batch interaction:  1738
# Batch interaction:  1739
# Batch interaction:  1740
# Batch interaction:  1741
# Batch interaction:  1742
# Batch interaction:  1743
# Batch interaction:  1744
# Batch interaction:  1745
# Batch interaction:  1746
# Batch interaction:  1747
# Batch interaction:  1748
# Batch interaction:  1749
# Batch interaction:  1750
# Batch interaction:  1751
# Batch interaction:  1752
# Batch interaction:  1753
# Batch interaction:  1754
# Batch interaction:  1755
# Batch interaction:  1756
# Batch interaction:  1757
# Batch interaction:  1758
# Batch interaction:  1759
# Batch interaction:  1760
# Batch interaction:  1761
# Batch interaction:  1762
# Batch interaction:  1763
# Batch interaction:  1764
# Batch interaction:  1765
# Batch interaction:  1766
# Batch interaction:  1767
# Batch interaction:  1768
# Batch interaction:  1769
# Batch interaction:  1770
# Batch interaction:  1771
# Batch interaction:  1772
# Batch interaction:  1773
# Batch interaction:  1774
# Batch interaction:  1775
# Batch interaction:  1776
# Batch interaction:  1777
# Batch interaction:  1778
# Batch interaction:  1779
# Batch interaction:  1780
# Batch interaction:  1781
# Batch interaction:  1782
# Batch interaction:  1783
# Batch interaction:  1784
# Batch interaction:  1785
# Batch interaction:  1786
# Batch interaction:  1787
# Batch interaction:  1788
# Batch interaction:  1789
# Batch interaction:  1790
# Batch interaction:  1791
# Batch interaction:  1792
# Batch interaction:  1793
# Batch interaction:  1794
# Batch interaction:  1795
# Batch interaction:  1796
# Batch interaction:  1797
# Batch interaction:  1798
# Batch interaction:  1799
# Batch interaction:  1800
# Training accuracy: tensor(0.8666)
# Batch interaction:  1801
# Batch interaction:  1802
# Batch interaction:  1803
# Batch interaction:  1804
# Batch interaction:  1805
# Batch interaction:  1806
# Batch interaction:  1807
# Batch interaction:  1808
# Batch interaction:  1809
# Batch interaction:  1810
# Batch interaction:  1811
# Batch interaction:  1812
# Batch interaction:  1813
# Batch interaction:  1814
# Batch interaction:  1815
# Batch interaction:  1816
# Batch interaction:  1817
# Batch interaction:  1818
# Batch interaction:  1819
# Batch interaction:  1820
# Batch interaction:  1821
# Batch interaction:  1822
# Batch interaction:  1823
# Batch interaction:  1824
# Batch interaction:  1825
# Batch interaction:  1826
# Batch interaction:  1827
# Batch interaction:  1828
# Batch interaction:  1829
# Batch interaction:  1830
# Batch interaction:  1831
# Batch interaction:  1832
# Batch interaction:  1833
# Batch interaction:  1834
# Batch interaction:  1835
# Batch interaction:  1836
# Batch interaction:  1837
# Batch interaction:  1838
# Batch interaction:  1839
# Batch interaction:  1840
# Batch interaction:  1841
# Batch interaction:  1842
# Batch interaction:  1843
# Batch interaction:  1844
# Batch interaction:  1845
# Batch interaction:  1846
# Batch interaction:  1847
# Batch interaction:  1848
# Batch interaction:  1849
# Batch interaction:  1850
# Batch interaction:  1851
# Batch interaction:  1852
# Batch interaction:  1853
# Batch interaction:  1854
# Batch interaction:  1855
# Batch interaction:  1856
# Batch interaction:  1857
# Batch interaction:  1858
# Batch interaction:  1859
# Batch interaction:  1860
# Batch interaction:  1861
# Batch interaction:  1862
# Batch interaction:  1863
# Batch interaction:  1864
# Batch interaction:  1865
# Batch interaction:  1866
# Batch interaction:  1867
# Batch interaction:  1868
# Batch interaction:  1869
# Batch interaction:  1870
# Batch interaction:  1871
# Batch interaction:  1872
# Batch interaction:  1873
# Batch interaction:  1874
# Batch interaction:  1875
# Batch interaction:  1876
# Batch interaction:  1877
# Batch interaction:  1878
# Batch interaction:  1879
# Batch interaction:  1880
# Batch interaction:  1881
# Batch interaction:  1882
# Batch interaction:  1883
# Batch interaction:  1884
# Batch interaction:  1885
# Batch interaction:  1886
# Batch interaction:  1887
# Batch interaction:  1888
# Batch interaction:  1889
# Batch interaction:  1890
# Batch interaction:  1891
# Batch interaction:  1892
# Batch interaction:  1893
# Batch interaction:  1894
# Batch interaction:  1895
# Batch interaction:  1896
# Batch interaction:  1897
# Batch interaction:  1898
# Batch interaction:  1899
# Batch interaction:  1900
# Training accuracy: tensor(0.8668)
# Batch interaction:  1901
# Batch interaction:  1902
# Batch interaction:  1903
# Batch interaction:  1904
# Batch interaction:  1905
# Batch interaction:  1906
# Batch interaction:  1907
# Batch interaction:  1908
# Batch interaction:  1909
# Batch interaction:  1910
# Batch interaction:  1911
# Batch interaction:  1912
# Batch interaction:  1913
# Batch interaction:  1914
# Batch interaction:  1915
# Batch interaction:  1916
# Batch interaction:  1917
# Batch interaction:  1918
# Batch interaction:  1919
# Batch interaction:  1920
# Batch interaction:  1921
# Batch interaction:  1922
# Batch interaction:  1923
# Batch interaction:  1924
# Batch interaction:  1925
# Batch interaction:  1926
# Batch interaction:  1927
# Batch interaction:  1928
# Batch interaction:  1929
# Batch interaction:  1930
# Batch interaction:  1931
# Batch interaction:  1932
# Batch interaction:  1933
# Batch interaction:  1934
# Batch interaction:  1935
# Batch interaction:  1936
# Batch interaction:  1937
# Batch interaction:  1938
# ...
# Batch interaction:  9765
# Batch interaction:  9766
# Batch interaction:  9767
# Batch interaction:  9768
# Batch interaction:  9769
# Batch interaction:  9770
# Batch interaction:  9771
# Batch interaction:  9772
# Batch interaction:  9773
# Batch interaction:  9774
# Batch interaction:  9775
# Batch interaction:  9776
# Batch interaction:  9777
# Batch interaction:  9778
# Batch interaction:  9779
# Batch interaction:  9780
# Batch interaction:  9781
# Batch interaction:  9782
# Batch interaction:  9783
# Batch interaction:  9784
# Batch interaction:  9785
# Batch interaction:  9786
# Batch interaction:  9787
# Batch interaction:  9788
# Batch interaction:  9789
# Batch interaction:  9790
# Batch interaction:  9791
# Batch interaction:  9792
# Batch interaction:  9793
# Batch interaction:  9794
# Batch interaction:  9795
# Batch interaction:  9796
# Batch interaction:  9797
# Batch interaction:  9798
# Batch interaction:  9799
# Batch interaction:  9800
# Training accuracy: tensor(0.8751)
# Batch interaction:  9801
# Batch interaction:  9802
# Batch interaction:  9803
# Batch interaction:  9804
# Batch interaction:  9805
# Batch interaction:  9806
# Batch interaction:  9807
# Batch interaction:  9808
# Batch interaction:  9809
# Batch interaction:  9810
# Batch interaction:  9811
# Batch interaction:  9812
# Batch interaction:  9813
# Batch interaction:  9814
# Batch interaction:  9815
# Batch interaction:  9816
# Batch interaction:  9817
# Batch interaction:  9818
# Batch interaction:  9819
# Batch interaction:  9820
# Batch interaction:  9821
# Batch interaction:  9822
# Batch interaction:  9823
# Batch interaction:  9824
# Batch interaction:  9825
# Batch interaction:  9826
# Batch interaction:  9827
# Batch interaction:  9828
# Batch interaction:  9829
# Batch interaction:  9830
# Batch interaction:  9831
# Batch interaction:  9832
# Batch interaction:  9833
# Batch interaction:  9834
# Batch interaction:  9835
# Batch interaction:  9836
# Batch interaction:  9837
# Batch interaction:  9838
# Batch interaction:  9839
# Batch interaction:  9840
# Batch interaction:  9841
# Batch interaction:  9842
# Batch interaction:  9843
# Batch interaction:  9844
# Batch interaction:  9845
# Batch interaction:  9846
# Batch interaction:  9847
# Batch interaction:  9848
# Batch interaction:  9849
# Batch interaction:  9850
# Batch interaction:  9851
# Batch interaction:  9852
# Batch interaction:  9853
# Batch interaction:  9854
# Batch interaction:  9855
# Batch interaction:  9856
# Batch interaction:  9857
# Batch interaction:  9858
# Batch interaction:  9859
# Batch interaction:  9860
# Batch interaction:  9861
# Batch interaction:  9862
# Batch interaction:  9863
# Batch interaction:  9864
# Batch interaction:  9865
# Batch interaction:  9866
# Batch interaction:  9867
# Batch interaction:  9868
# Batch interaction:  9869
# Batch interaction:  9870
# Batch interaction:  9871
# Batch interaction:  9872
# Batch interaction:  9873
# Batch interaction:  9874
# Batch interaction:  9875
# Batch interaction:  9876
# Batch interaction:  9877
# Batch interaction:  9878
# Batch interaction:  9879
# Batch interaction:  9880
# Batch interaction:  9881
# Batch interaction:  9882
# Batch interaction:  9883
# Batch interaction:  9884
# Batch interaction:  9885
# Batch interaction:  9886
# Batch interaction:  9887
# Batch interaction:  9888
# Batch interaction:  9889
# Batch interaction:  9890
# Batch interaction:  9891
# Batch interaction:  9892
# Batch interaction:  9893
# Batch interaction:  9894
# Batch interaction:  9895
# Batch interaction:  9896
# Batch interaction:  9897
# Batch interaction:  9898
# Batch interaction:  9899
# Batch interaction:  9900
# Training accuracy: tensor(0.8751)
# Batch interaction:  9901
# Batch interaction:  9902
# Batch interaction:  9903
# Batch interaction:  9904
# Batch interaction:  9905
# Batch interaction:  9906
# Batch interaction:  9907
# Batch interaction:  9908
# Batch interaction:  9909
# Batch interaction:  9910
# Batch interaction:  9911
# Batch interaction:  9912
# Batch interaction:  9913
# Batch interaction:  9914
# Batch interaction:  9915
# Batch interaction:  9916
# Batch interaction:  9917
# Batch interaction:  9918
# Batch interaction:  9919
# Batch interaction:  9920
# Batch interaction:  9921
# Batch interaction:  9922
# Batch interaction:  9923
# Batch interaction:  9924
# Batch interaction:  9925
# Batch interaction:  9926
# Batch interaction:  9927
# Batch interaction:  9928
# Batch interaction:  9929
# Batch interaction:  9930
# Batch interaction:  9931
# Batch interaction:  9932
# Batch interaction:  9933
# Batch interaction:  9934
# Batch interaction:  9935
# Batch interaction:  9936
# Batch interaction:  9937
# Batch interaction:  9938
# Batch interaction:  9939
# Batch interaction:  9940
# Batch interaction:  9941
# Batch interaction:  9942
# Batch interaction:  9943
# Batch interaction:  9944
# Batch interaction:  9945
# Batch interaction:  9946
# Batch interaction:  9947
# Batch interaction:  9948
# Batch interaction:  9949
# Batch interaction:  9950
# Batch interaction:  9951
# Batch interaction:  9952
# Batch interaction:  9953
# Batch interaction:  9954
# Batch interaction:  9955
# Batch interaction:  9956
# Batch interaction:  9957
# Batch interaction:  9958
# Batch interaction:  9959
# Batch interaction:  9960
# Batch interaction:  9961
# Batch interaction:  9962
# Batch interaction:  9963
# Batch interaction:  9964
# Batch interaction:  9965
# Batch interaction:  9966
# Batch interaction:  9967
# Batch interaction:  9968
# Batch interaction:  9969
# Batch interaction:  9970
# Batch interaction:  9971
# Batch interaction:  9972
# Batch interaction:  9973
# Batch interaction:  9974
# Batch interaction:  9975
# Batch interaction:  9976
# Batch interaction:  9977
# Batch interaction:  9978
# Batch interaction:  9979
# Batch interaction:  9980
# Batch interaction:  9981
# Batch interaction:  9982
# Batch interaction:  9983
# Batch interaction:  9984
# Batch interaction:  9985
# Batch interaction:  9986
# Batch interaction:  9987
# Batch interaction:  9988
# Batch interaction:  9989
# Batch interaction:  9990
# Batch interaction:  9991
# Batch interaction:  9992
# Batch interaction:  9993
# Batch interaction:  9994
# Batch interaction:  9995
# Batch interaction:  9996
# Batch interaction:  9997
# Batch interaction:  9998
# Batch interaction:  9999
# Batch interaction:  10000
# Training accuracy: tensor(0.8752)
# Batch interaction:  10001
# Batch interaction:  10002
# Batch interaction:  10003
# Batch interaction:  10004
# Batch interaction:  10005
# Batch interaction:  10006
# Batch interaction:  10007
# Batch interaction:  10008
# Batch interaction:  10009
# Batch interaction:  10010
# Batch interaction:  10011
# Batch interaction:  10012
# Batch interaction:  10013
# Batch interaction:  10014
# Batch interaction:  10015
# Batch interaction:  10016
# Batch interaction:  10017
# Batch interaction:  10018
# Batch interaction:  10019
# Batch interaction:  10020
# Batch interaction:  10021
# Batch interaction:  10022
# Batch interaction:  10023
# Batch interaction:  10024
# Batch interaction:  10025
# Batch interaction:  10026
# Batch interaction:  10027
# Batch interaction:  10028
# Batch interaction:  10029
# Batch interaction:  10030
# Batch interaction:  10031
# Batch interaction:  10032
# Batch interaction:  10033
# Batch interaction:  10034
# Batch interaction:  10035
# Batch interaction:  10036
# Batch interaction:  10037
# Batch interaction:  10038
# Batch interaction:  10039
# Batch interaction:  10040
# Batch interaction:  10041
# Batch interaction:  10042
# Batch interaction:  10043
# Batch interaction:  10044
# Batch interaction:  10045
# Batch interaction:  10046
# Batch interaction:  10047
# Batch interaction:  10048
# Batch interaction:  10049
# Batch interaction:  10050
# Batch interaction:  10051
# Batch interaction:  10052
# Batch interaction:  10053
# Batch interaction:  10054
# Batch interaction:  10055
# Batch interaction:  10056
# Batch interaction:  10057
# Batch interaction:  10058
# Batch interaction:  10059
# Batch interaction:  10060
# Batch interaction:  10061
# Batch interaction:  10062
# Batch interaction:  10063
# Batch interaction:  10064
# Batch interaction:  10065
# Batch interaction:  10066
# Batch interaction:  10067
# Batch interaction:  10068
# Batch interaction:  10069
# Batch interaction:  10070
# Batch interaction:  10071
# Batch interaction:  10072
# Batch interaction:  10073
# Batch interaction:  10074
# Batch interaction:  10075
# Batch interaction:  10076
# Batch interaction:  10077
# Batch interaction:  10078
# Batch interaction:  10079
# Batch interaction:  10080
# Batch interaction:  10081
# Batch interaction:  10082
# Batch interaction:  10083
# Batch interaction:  10084
# Batch interaction:  10085
# Batch interaction:  10086
# Batch interaction:  10087
# Batch interaction:  10088
# Batch interaction:  10089
# Batch interaction:  10090
# Batch interaction:  10091
# Batch interaction:  10092
# Batch interaction:  10093
# Batch interaction:  10094
# Batch interaction:  10095
# Batch interaction:  10096
# Batch interaction:  10097
# Batch interaction:  10098
# Batch interaction:  10099
# Batch interaction:  10100
# Training accuracy: tensor(0.8753)
# Batch interaction:  10101
# Batch interaction:  10102
# Batch interaction:  10103
# Batch interaction:  10104
# Batch interaction:  10105
# Batch interaction:  10106
# Batch interaction:  10107
# Batch interaction:  10108
# Batch interaction:  10109
# Batch interaction:  10110
# Batch interaction:  10111
# Batch interaction:  10112
# Batch interaction:  10113
# Batch interaction:  10114
# Batch interaction:  10115
# Batch interaction:  10116
# Batch interaction:  10117
# Batch interaction:  10118
# Batch interaction:  10119
# Batch interaction:  10120
# Batch interaction:  10121
# Batch interaction:  10122
# Batch interaction:  10123
# Batch interaction:  10124
# Batch interaction:  10125
# Batch interaction:  10126
# Batch interaction:  10127
# Batch interaction:  10128
# Batch interaction:  10129
# Batch interaction:  10130
# Batch interaction:  10131
# Batch interaction:  10132
# Batch interaction:  10133
# Batch interaction:  10134
# Batch interaction:  10135
# Batch interaction:  10136
# Batch interaction:  10137
# Batch interaction:  10138
# Batch interaction:  10139
# Batch interaction:  10140
# Batch interaction:  10141
# Batch interaction:  10142
# Batch interaction:  10143
# Batch interaction:  10144
# Batch interaction:  10145
# Batch interaction:  10146
# Batch interaction:  10147
# Batch interaction:  10148
# Batch interaction:  10149
# Batch interaction:  10150
# Batch interaction:  10151
# Batch interaction:  10152
# Batch interaction:  10153
# Batch interaction:  10154
# Batch interaction:  10155
# Batch interaction:  10156
# Batch interaction:  10157
# Batch interaction:  10158
# Batch interaction:  10159
# Batch interaction:  10160
# Batch interaction:  10161
# Batch interaction:  10162
# Batch interaction:  10163
# Batch interaction:  10164
# Batch interaction:  10165
# Batch interaction:  10166
# Batch interaction:  10167
# Batch interaction:  10168
# Batch interaction:  10169
# Batch interaction:  10170
# Batch interaction:  10171
# Batch interaction:  10172
# Batch interaction:  10173
# Batch interaction:  10174
# Batch interaction:  10175
# Batch interaction:  10176
# Batch interaction:  10177
# Batch interaction:  10178
# Batch interaction:  10179
# Batch interaction:  10180
# Batch interaction:  10181
# Batch interaction:  10182
# Batch interaction:  10183
# Batch interaction:  10184
# Batch interaction:  10185
# Batch interaction:  10186
# Batch interaction:  10187
# Batch interaction:  10188
# Batch interaction:  10189
# Batch interaction:  10190
# Batch interaction:  10191
# Batch interaction:  10192
# Batch interaction:  10193
# Batch interaction:  10194
# Batch interaction:  10195
# Batch interaction:  10196
# Batch interaction:  10197
# Batch interaction:  10198
# Batch interaction:  10199
# Batch interaction:  10200
# Training accuracy: tensor(0.8754)
# Batch interaction:  10201
# Batch interaction:  10202
# Batch interaction:  10203
# Batch interaction:  10204
# Batch interaction:  10205
# Batch interaction:  10206
# Batch interaction:  10207
# Batch interaction:  10208
# Batch interaction:  10209
# Batch interaction:  10210
# Batch interaction:  10211
# Batch interaction:  10212
# Batch interaction:  10213
# Batch interaction:  10214
# Batch interaction:  10215
# Batch interaction:  10216
# Batch interaction:  10217
# Batch interaction:  10218
# Batch interaction:  10219
# Batch interaction:  10220
# Batch interaction:  10221
# Batch interaction:  10222
# Batch interaction:  10223
# Batch interaction:  10224
# Batch interaction:  10225
# Batch interaction:  10226
# Batch interaction:  10227
# Batch interaction:  10228
# Batch interaction:  10229
# Batch interaction:  10230
# Batch interaction:  10231
# Batch interaction:  10232
# Batch interaction:  10233
# Batch interaction:  10234
# Batch interaction:  10235
# Batch interaction:  10236
# Batch interaction:  10237
# Batch interaction:  10238
# Batch interaction:  10239
# Batch interaction:  10240
# Batch interaction:  10241
# Batch interaction:  10242
# Batch interaction:  10243
# Batch interaction:  10244
# Batch interaction:  10245
# Batch interaction:  10246
# Batch interaction:  10247
# Batch interaction:  10248
# Batch interaction:  10249
# Batch interaction:  10250
# Batch interaction:  10251
# Batch interaction:  10252
# Batch interaction:  10253
# Batch interaction:  10254
# Batch interaction:  10255
# Batch interaction:  10256
# Batch interaction:  10257
# Batch interaction:  10258
# Batch interaction:  10259
# Batch interaction:  10260
# Batch interaction:  10261
# Batch interaction:  10262
# Batch interaction:  10263
# Batch interaction:  10264
# Batch interaction:  10265
# Batch interaction:  10266
# Batch interaction:  10267
# Batch interaction:  10268
# Batch interaction:  10269
# Batch interaction:  10270
# Batch interaction:  10271
# Batch interaction:  10272
# Batch interaction:  10273
# Batch interaction:  10274
# Batch interaction:  10275
# Batch interaction:  10276
# Batch interaction:  10277
# Batch interaction:  10278
# Batch interaction:  10279
# Batch interaction:  10280
# Batch interaction:  10281
# Batch interaction:  10282
# Batch interaction:  10283
# Batch interaction:  10284
# Batch interaction:  10285
# Batch interaction:  10286
# Batch interaction:  10287
# Batch interaction:  10288
# Batch interaction:  10289
# Batch interaction:  10290
# Batch interaction:  10291
# Batch interaction:  10292
# Batch interaction:  10293
# Batch interaction:  10294
# Batch interaction:  10295
# Batch interaction:  10296
# Batch interaction:  10297
# Batch interaction:  10298
# Batch interaction:  10299
# Batch interaction:  10300
# Training accuracy: tensor(0.8754)
# Batch interaction:  10301
# Batch interaction:  10302
# Batch interaction:  10303
# Batch interaction:  10304
# Batch interaction:  10305
# Batch interaction:  10306
# Batch interaction:  10307
# Batch interaction:  10308
# Batch interaction:  10309
# Batch interaction:  10310
# Batch interaction:  10311
# Batch interaction:  10312
# Batch interaction:  10313
# Batch interaction:  10314
# Batch interaction:  10315
# Batch interaction:  10316
# Batch interaction:  10317
# Batch interaction:  10318
# Batch interaction:  10319
# Batch interaction:  10320
# Batch interaction:  10321
# Batch interaction:  10322
# Batch interaction:  10323
# Batch interaction:  10324
# Batch interaction:  10325
# Batch interaction:  10326
# Batch interaction:  10327
# Batch interaction:  10328
# Batch interaction:  10329
# Batch interaction:  10330
# Batch interaction:  10331
# Batch interaction:  10332
# Batch interaction:  10333
# Batch interaction:  10334
# Batch interaction:  10335
# Batch interaction:  10336
# Batch interaction:  10337
# Batch interaction:  10338
# Batch interaction:  10339
# Batch interaction:  10340
# Batch interaction:  10341
# Batch interaction:  10342
# Batch interaction:  10343
# Batch interaction:  10344
# Batch interaction:  10345
# Batch interaction:  10346
# Batch interaction:  10347
# Batch interaction:  10348
# Batch interaction:  10349
# Batch interaction:  10350
# Batch interaction:  10351
# Batch interaction:  10352
# Batch interaction:  10353
# Batch interaction:  10354
# Batch interaction:  10355
# Batch interaction:  10356
# Batch interaction:  10357
# Batch interaction:  10358
# Batch interaction:  10359
# Batch interaction:  10360
# Batch interaction:  10361
# Batch interaction:  10362
# Batch interaction:  10363
# Batch interaction:  10364
# Batch interaction:  10365
# Batch interaction:  10366
# Batch interaction:  10367
# Batch interaction:  10368
# Batch interaction:  10369
# Batch interaction:  10370
# Batch interaction:  10371
# Batch interaction:  10372
# Batch interaction:  10373
# Batch interaction:  10374
# Batch interaction:  10375
# Batch interaction:  10376
# Batch interaction:  10377
# Batch interaction:  10378
# Batch interaction:  10379
# Batch interaction:  10380

# %%
# Save model
torch.save(model_CNN_image_text_final.state_dict(), 'model_with_images_test.pt')

# %% [markdown]
# ### Model evaluation

# %%
counter = 0

images_tensor = torch.zeros(60,3,560,560)
titles_tensor = torch.zeros(60,15)
labels_tensor = torch.zeros(60)

predictions = np.array([])
labels_test = np.array([])

# Validation pass

with torch.no_grad():
    
 for i in range(len(test_images_final)):
    
    # First check if image is available
    
    img = cv2.imread(PATH + test_images_final[i])
        
    if type(img) is not type(None):
        
        # Add 1 to counter
        
        counter += 1
               
        # Pad it with zeos to obtain 560 x 560 shape
        
        img_padded = pad_images(img)
        
        # Store image and corresponding title and label 
        images_tensor[counter-1, :,:,:] = torch.from_numpy(img_padded)
        titles_tensor[counter-1, :] = torch.from_numpy(test_tokenized_pad[i]).int()
        labels_tensor[counter - 1] = test_labels[i] 
        
        if counter%60 == 0:

           # Pass image and text through the different layers
            
           out = model_CNN_image_text_final.forward(images_tensor, titles_tensor.int())         
                 
           # Obtain predictions
            
           top_p, top_class = out.topk(1, dim=1) 
           predictions = np.concatenate((predictions, top_class.numpy().reshape(-1)))
           labels_test =  np.concatenate((labels_test, labels_tensor.numpy()))
        
           images_tensor = torch.zeros(60,3,560,560)
           titles_tensor = torch.zeros(60,15)
           labels_tensor = torch.zeros(60)
            
           counter = 0

# %% [markdown]
# Finally we can obtain the results of the model evaluation over the test data.

# %%
print(classification_report(labels_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.88      0.86     23489
#          1.0       0.82      0.72      0.77      3513
#          2.0       0.77      0.76      0.76     11290
#          3.0       0.46      0.25      0.32      1223
#          4.0       1.00      1.00      1.00     17400
#          5.0       0.75      0.79      0.77      2305
#
#     accuracy                           0.87     59220
#    macro avg       0.77      0.73      0.75     59220
# weighted avg       0.86      0.87      0.86     59220

# %%
# Classification report without 0 label
print(classification_report(np.array(labels_test).reshape(len(labels_test),1),predictions, labels = [1,2,3,4,5]))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.82      0.72      0.77      3513
#            2       0.77      0.76      0.76     11290
#            3       0.46      0.25      0.32      1223
#            4       1.00      1.00      1.00     17400
#            5       0.75      0.79      0.77      2305
#
#    micro avg       0.88      0.86      0.87     35731
#    macro avg       0.76      0.70      0.72     35731
# weighted avg       0.87      0.86      0.86     35731

# %%
# Confusion matrix
print(confusion_matrix(np.array(labels_test).reshape(len(labels_test),1),predictions))
# Out:
# [[20703   283  2048   192     4   259]
#  [  604  2540   262    43     9    55]
#  [ 2229   175  8564    76     7   239]
#  [  618    46   190   306     4    59]
#  [    4    10    17     0 17367     2]
#  [  275    53   110    46     0  1821]]
